# %% [markdown]
# # Dependencies

# %%
# %load_ext autoreload
# %autoreload 2

# For debugging turn on logging to console
import logging
logging.basicConfig(level=logging.DEBUG)
log = logging.getLogger(__name__)

# mongodb
import pymongo as pm

# fine-tuned newspaper lib
from resources.newspaper import newspaper
from resources.newspaper.newspaper.source import Source
from resources.newspaper.newspaper.article import Article

import bs4 as bs
from urllib.parse import urljoin
from dateutil.parser import parse as date_parser
from time import sleep
import random
import pytz
import datetime

import requests

logging.getLogger('urllib3').setLevel(logging.WARNING)

# %%
# for infinite scroll page
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import Select
from selenium.webdriver.support.ui import WebDriverWait
from selenium.common.exceptions import TimeoutException
from selenium.webdriver.support import expected_conditions as EC
from selenium.common.exceptions import NoSuchElementException
from selenium.common.exceptions import NoAlertPresentException
import sys

import unittest, time, re

# to divert selenium log stream away
logging.getLogger('selenium').setLevel(logging.WARNING)

# %% [markdown]
# # Helpers

# %%
# Initialize PyMongo to work with MongoDBs
conn = 'mongodb://localhost:27017'
client = pm.MongoClient(conn, maxPoolSize=200)

# define db 
# DB_NAME = 'scrape'
DB_NAME = 'FINALP'
db = client[DB_NAME]

def saveToDB(db, collection, url, html, meta={}):
    """
    Saves a document to mongoDB, making sure there are no duplicates by 
    'url' value
    
    Parameters:
    --------
    db, collection  : mongo db connection
    url, html, meta : values to store
    
    Returns:
    --------
    Saved document
    """
    collection = db[collection]
    collection.update_one(
        {'url' : url},
        {
            '$set':
                {'url' : url,
                 'html' : html,
                 'meta' : meta
                }
        }
        ,
        upsert=True
    )
    log.debug(f'Saved to DB')

def scrape(url, db, collection):
    '''
    Scrapes an article from the 'url' up to the 'latest_date'
    
    Parameters:
    --------
    url         : main news website url
    date        : YYYY-MM-DD
    db          : database name
    collection  : mongodb collection
    
    Returns:
    --------
    Article's html and features stored to db, 
    Article's publish date
    
    '''
    log.debug(f"Exctracting features from {url}")
    try:
        article = Article(url)
        article.download()
        # the below method may only extract a snippet... 
        # check the database for results of text extraction
        # and apply additional processing if needed after 
        # article has been stored in the DB
        # see code below Newrepublic for example
        article.parse()
    except Exception as e:
        log.critical(f'Data not saved: {e}')
        return datetime.datetime.now()
    
    saveToDB(db, collection, article.url, article.html, meta={
        'date'    :article.publish_date,
        'title'   :article.title,
        'text'    :article.text,
        'authors' :article.authors
    })
    
    return article.publish_date

def addToDB(DB_NAME,COL_NAME,PATH,FILE):
    '''
    Imports a file into mongoDB
    
    Parameters:
    --------
    DB_NAME : Name of the database to connect to
    COL_NAME: Name of the collection to create
    PATH    : Path to folder with the file
    FILE  : Filename
    
    Returns:
    --------
    Collection COL_NAME in DB_NAME database
    '''
    # !mongoimport --db {DB_NAME} --collection {COL_NAME} --file {PATH+FILE} --batchSize 1
    print(f'Collection {COL_NAME} in {DB_NAME} database created')

# %% [markdown]
# # NY Post

# %%
collection = 'nypost'
source = 'https://nypost.com/news/'

class Sel(unittest.TestCase):
    def setUp(self):
        self.driver = webdriver.Chrome()
        self.driver.implicitly_wait(30)
        self.base_url = source
        self.verificationErrors = []
        self.accept_next_alert = True
    def getPage(self):
        driver = self.driver
        delay = 2
        driver.get(self.base_url)
        html_source = driver.page_source
        self.html = html_source.encode('utf-8')
        return self.html
    def scrollDown(self):
        driver = self.driver
        driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
        self.html = driver.page_source.encode('utf-8')
        return driver.page_source 
    def shutdown(self):
        driver = self.driver
        driver.quit()

data = Sel()

data.setUp()
data.getPage()
page = 1

utc=pytz.UTC
earliest_date = utc.localize(date_parser('2017-01-01'))

scraped_urls = []

while True:
    log.debug(f'NEXT SCROLL (#{page})')
    page += 1
    
    html = data.scrollDown()
    soup = bs.BeautifulSoup(html,'lxml')

    for link in soup.find('div', {"id":"primary"}).findAll('a'):
        url = urljoin(source, link['href'])
        if url and url not in scraped_urls:
            scraped_urls.append(url)
            log.debug(f'Processing url: {url}')
            article_date = scrape(url, db, collection)
    try:
        if article_date < earliest_date:
            log.debug(f'Reached earliest date requested: {article_date}')
            break
    except Exception as e:
        log.debug(f"Something is wrong: {e}")
data.shutdown()

# %%
collection = 'nypost'
source = 'https://nypost.com/news/page/'
page   = 1

utc=pytz.UTC
earliest_date = date_parser('2017-01-01')

while True:
    log.debug(f'\n\n PROCESSING PAGE: {source+str(page)}\n\n\
              ====================================\n\n')
    s = Source(source+str(page))
    page += 1
    s.download()
    soup = bs.BeautifulSoup(s.html,'lxml')

    for h3 in soup.find('div', {"id":"primary"}).findAll('h3'):
        for link in h3.findAll('a'):
            url = link['href']
            log.debug(f'Processing url: {url}')

            try:
                article_date = scrape(url, db, collection)
            except Exception as e:
                log.debug(e)
                article_date = earliest_date + 1 #to make sure scraping continues

        try:
            if article_date < earliest_date:
                log.debug(f'Reached earliest date requested: {article_date}')
                break
        except Exception as e:
            log.debug(f'Exception: {e}')
            continue
# Out:
# DEBUG:__main__:
#
#  PROCESSING PAGE: https://nypost.com/news/page/1
#
#               ====================================
#
#
# DEBUG:__main__:Processing url: https://nypost.com/2018/07/30/pantsless-doctor-busted-in-bed-with-underage-boy/
# DEBUG:__main__:Exctracting features from https://nypost.com/2018/07/30/pantsless-doctor-busted-in-bed-with-underage-boy/
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://nypost.com/2018/07/30/us-teen-studying-abroad-drowns-while-swimming-in-israel/
# DEBUG:__main__:Exctracting features from https://nypost.com/2018/07/30/us-teen-studying-abroad-drowns-while-swimming-in-israel/
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://nypost.com/2018/07/30/investigators-gave-up-search-for-missing-flight-mh370-months-ago/
# DEBUG:__main__:Exctracting features from https://nypost.com/2018/07/30/investigators-gave-up-search-for-missing-flight-mh370-months-ago/
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://nypost.com/2018/07/30/canada-dry-ginger-ale-is-a-sham-suit/
# DEBUG:__main__:Exctracting features from https://nypost.com/2018/07/30/canada-dry-ginger-ale-is-a-sham-suit/
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://nypost.com/2018/07/30/cop-fired-after-allegedly-kicking-pregnant-woman-in-stomach/
# DEBUG:__main__:Exctracting features from https://nypost.com/2018/07/30/cop-fired-after-allegedly-kicking-pregnant-woman-in-stomach/
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://nypost.com/2018/07/30/sheriffs-alleged-affair-with-deputy-rocks-small-rural-county/
# DEBUG:__main__:Exctracting features from https://nypost.com/2018/07/30/sheriffs-alleged-affair-with-deputy-rocks-small-rural-county/
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://nypost.com/2018/07/30/bigfoot-porn-shakes-up-virginia-congressional-race/
# DEBUG:__main__:Exctracting features from https://nypost.com/2018/07/30/bigfoot-porn-shakes-up-virginia-congressional-race/
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://nypost.com/2018/07/30/austin-considers-renaming-city-over-ties-to-slavery/
# DEBUG:__main__:Exctracting features from https://nypost.com/2018/07/30/austin-considers-renaming-city-over-ties-to-slavery/
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://nypost.com/2018/07/30/sacha-baron-cohen-confronts-roy-moore-with-pedophile-detector/
# DEBUG:__main__:Exctracting features from https://nypost.com/2018/07/30/sacha-baron-cohen-confronts-roy-moore-with-pedophile-detector/
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://nypost.com/2018/07/30/australian-bishop-convicted-of-sex-abuse-cover-up-resigns/
# DEBUG:__main__:Exctracting features from https://nypost.com/2018/07/30/australian-bishop-convicted-of-sex-abuse-cover-up-resigns/
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:
#
#  PROCESSING PAGE: https://nypost.com/news/page/2
#
#               ====================================
#
#
# DEBUG:__main__:Processing url: https://nypost.com/2018/07/30/australian-bishop-convicted-of-sex-abuse-cover-up-resigns/
# DEBUG:__main__:Exctracting features from https://nypost.com/2018/07/30/australian-bishop-convicted-of-sex-abuse-cover-up-resigns/
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://nypost.com/2018/07/30/trump-repeats-his-call-for-a-border-wall/
# DEBUG:__main__:Exctracting features from https://nypost.com/2018/07/30/trump-repeats-his-call-for-a-border-wall/
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://nypost.com/2018/07/30/man-stabbed-grandmother-because-he-was-sick-of-caring-for-her-cops/
# DEBUG:__main__:Exctracting features from https://nypost.com/2018/07/30/man-stabbed-grandmother-because-he-was-sick-of-caring-for-her-cops/
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://nypost.com/2018/07/30/ruth-bader-ginsburg-ive-got-at-least-five-more-years/
# DEBUG:__main__:Exctracting features from https://nypost.com/2018/07/30/ruth-bader-ginsburg-ive-got-at-least-five-more-years/
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://nypost.com/2018/07/29/mom-says-daughter-died-after-medics-assumed-she-couldnt-afford-ambulance/
# DEBUG:__main__:Exctracting features from https://nypost.com/2018/07/29/mom-says-daughter-died-after-medics-assumed-she-couldnt-afford-ambulance/
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://nypost.com/2018/07/29/trump-says-the-media-puts-the-lives-of-many-at-risk-in-twitter-rant/
# DEBUG:__main__:Exctracting features from https://nypost.com/2018/07/29/trump-says-the-media-puts-the-lives-of-many-at-risk-in-twitter-rant/
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://nypost.com/2018/07/29/woman-shoots-kills-husband-over-pornography-cops/
# DEBUG:__main__:Exctracting features from https://nypost.com/2018/07/29/woman-shoots-kills-husband-over-pornography-cops/
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://nypost.com/2018/07/29/homeless-man-saves-woman-who-jumped-from-bridge-police/
# DEBUG:__main__:Exctracting features from https://nypost.com/2018/07/29/homeless-man-saves-woman-who-jumped-from-bridge-police/
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://nypost.com/2018/07/29/spicers-lawyer-denies-racial-slur-accusation/
# DEBUG:__main__:Exctracting features from https://nypost.com/2018/07/29/spicers-lawyer-denies-racial-slur-accusation/
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://nypost.com/2018/07/29/man-caught-on-video-spewing-hate-at-couple-threatening-to-kill-kids/
# DEBUG:__main__:Exctracting features from https://nypost.com/2018/07/29/man-caught-on-video-spewing-hate-at-couple-threatening-to-kill-kids/
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:
#
#  PROCESSING PAGE: https://nypost.com/news/page/3
#
#               ====================================
#
#
# DEBUG:__main__:Processing url: https://nypost.com/2018/07/29/senator-says-staff-is-being-targeted-by-hackers/
# DEBUG:__main__:Exctracting features from https://nypost.com/2018/07/29/senator-says-staff-is-being-targeted-by-hackers/
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://nypost.com/2018/07/29/giuliani-cohens-recording-of-trump-will-help-the-president/
# DEBUG:__main__:Exctracting features from https://nypost.com/2018/07/29/giuliani-cohens-recording-of-trump-will-help-the-president/
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://nypost.com/2018/07/29/trump-says-he-had-interesting-meeting-with-ny-times-publisher/
# DEBUG:__main__:Exctracting features from https://nypost.com/2018/07/29/trump-says-he-had-interesting-meeting-with-ny-times-publisher/
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://nypost.com/2018/07/29/great-grandmother-and-kids-killed-in-california-wildfires/
# DEBUG:__main__:Exctracting features from https://nypost.com/2018/07/29/great-grandmother-and-kids-killed-in-california-wildfires/
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://nypost.com/2018/07/29/trump-willing-to-shut-down-government-over-border-security/
# DEBUG:__main__:Exctracting features from https://nypost.com/2018/07/29/trump-willing-to-shut-down-government-over-border-security/
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://nypost.com/2018/07/29/trump-says-his-poll-numbers-are-higher-than-lincolns-even-though-polling-didnt-exist-then/
# DEBUG:__main__:Exctracting features from https://nypost.com/2018/07/29/trump-says-his-poll-numbers-are-higher-than-lincolns-even-though-polling-didnt-exist-then/
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://nypost.com/2018/07/29/mom-of-woman-murdered-by-billionaire-boyfriend-hopes-he-goes-straight-to-hell/
# DEBUG:__main__:Exctracting features from https://nypost.com/2018/07/29/mom-of-woman-murdered-by-billionaire-boyfriend-hopes-he-goes-straight-to-hell/
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://nypost.com/2018/07/29/several-dead-injured-in-new-orleans-shooting/
# DEBUG:__main__:Exctracting features from https://nypost.com/2018/07/29/several-dead-injured-in-new-orleans-shooting/
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://nypost.com/2018/07/28/england-could-see-a-massive-onion-potato-shortage/
# DEBUG:__main__:Exctracting features from https://nypost.com/2018/07/28/england-could-see-a-massive-onion-potato-shortage/
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://nypost.com/2018/07/28/hundreds-attend-funeral-of-duck-boat-disaster-victims/
# DEBUG:__main__:Exctracting features from https://nypost.com/2018/07/28/hundreds-attend-funeral-of-duck-boat-disaster-victims/
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:
#
#  PROCESSING PAGE: https://nypost.com/news/page/4
#
#               ====================================
#
#
# DEBUG:__main__:Processing url: https://nypost.com/2018/07/28/california-wildfire-leaves-charred-remains-of-city-in-its-path/
# DEBUG:__main__:Exctracting features from https://nypost.com/2018/07/28/california-wildfire-leaves-charred-remains-of-city-in-its-path/
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://nypost.com/2018/07/28/jetblue-comes-through-after-bridesmaid-axed-from-wedding-party/
# DEBUG:__main__:Exctracting features from https://nypost.com/2018/07/28/jetblue-comes-through-after-bridesmaid-axed-from-wedding-party/
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://nypost.com/2018/07/28/2018-midterm-elections-set-to-be-most-expensive-in-history/
# DEBUG:__main__:Exctracting features from https://nypost.com/2018/07/28/2018-midterm-elections-set-to-be-most-expensive-in-history/
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://nypost.com/2018/07/28/homeless-man-hands-out-resumes-gets-hundreds-of-job-offers/
# DEBUG:__main__:Exctracting features from https://nypost.com/2018/07/28/homeless-man-hands-out-resumes-gets-hundreds-of-job-offers/
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://nypost.com/2018/07/28/meet-pakistans-playboy-turned-prime-minister/
# DEBUG:__main__:Exctracting features from https://nypost.com/2018/07/28/meet-pakistans-playboy-turned-prime-minister/
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://nypost.com/2018/07/28/kavanaugh-celebrates-senate-meetings-with-drinks-at-white-house/
# DEBUG:__main__:Exctracting features from https://nypost.com/2018/07/28/kavanaugh-celebrates-senate-meetings-with-drinks-at-white-house/
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://nypost.com/2018/07/28/trump-jokes-ivanka-couldve-married-tom-brady-instead-of-jared/
# DEBUG:__main__:Exctracting features from https://nypost.com/2018/07/28/trump-jokes-ivanka-couldve-married-tom-brady-instead-of-jared/
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://nypost.com/2018/07/28/judge-credits-blames-trump-admin-for-migrant-kids-situation/
# DEBUG:__main__:Exctracting features from https://nypost.com/2018/07/28/judge-credits-blames-trump-admin-for-migrant-kids-situation/
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://nypost.com/2018/07/28/another-palestinian-teenager-shot-dead-by-israeli-soldiers/
# DEBUG:__main__:Exctracting features from https://nypost.com/2018/07/28/another-palestinian-teenager-shot-dead-by-israeli-soldiers/
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://nypost.com/2018/07/28/russian-soldiers-stand-guard-at-trumps-walk-of-fame-star/
# DEBUG:__main__:Exctracting features from https://nypost.com/2018/07/28/russian-soldiers-stand-guard-at-trumps-walk-of-fame-star/
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:
#
#  PROCESSING PAGE: https://nypost.com/news/page/5
#
#               ====================================
#
#
# DEBUG:__main__:Processing url: https://nypost.com/2018/07/28/attackers-kill-3-at-afghanistan-midwife-training-center/
# DEBUG:__main__:Exctracting features from https://nypost.com/2018/07/28/attackers-kill-3-at-afghanistan-midwife-training-center/
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://nypost.com/2018/07/28/isis-linked-inmate-who-threatened-prince-george-stabbed-by-fellow-prisoner/
# DEBUG:__main__:Exctracting features from https://nypost.com/2018/07/28/isis-linked-inmate-who-threatened-prince-george-stabbed-by-fellow-prisoner/
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://nypost.com/2018/07/28/orca-mother-refused-to-leave-her-dead-calf-behind/
# DEBUG:__main__:Exctracting features from https://nypost.com/2018/07/28/orca-mother-refused-to-leave-her-dead-calf-behind/
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://pagesix.com/2018/07/28/presidential-hopefuls-head-to-the-hamptons/
# DEBUG:__main__:Exctracting features from https://pagesix.com/2018/07/28/presidential-hopefuls-head-to-the-hamptons/
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://nypost.com/2018/07/28/twins-died-hugging-their-grandparents-in-greece-wildfires/
# DEBUG:__main__:Exctracting features from https://nypost.com/2018/07/28/twins-died-hugging-their-grandparents-in-greece-wildfires/
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://nypost.com/2018/07/28/brigitte-macron-racking-up-big-beauty-bills-on-taxpayer-dime/
# DEBUG:__main__:Exctracting features from https://nypost.com/2018/07/28/brigitte-macron-racking-up-big-beauty-bills-on-taxpayer-dime/
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://nypost.com/2018/07/28/ex-classmate-confronts-spicer-with-n-word-accusation-at-book-signing/
# DEBUG:__main__:Exctracting features from https://nypost.com/2018/07/28/ex-classmate-confronts-spicer-with-n-word-accusation-at-book-signing/
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://nypost.com/2018/07/28/six-from-same-family-die-in-motel-fire/
# DEBUG:__main__:Exctracting features from https://nypost.com/2018/07/28/six-from-same-family-die-in-motel-fire/
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://nypost.com/2018/07/28/polar-bear-shot-dead-after-attacking-cruise-ship-worker-in-arctic/
# DEBUG:__main__:Exctracting features from https://nypost.com/2018/07/28/polar-bear-shot-dead-after-attacking-cruise-ship-worker-in-arctic/
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://nypost.com/2018/07/28/longest-lunar-eclipse-of-century-was-visible-everywhere-but-us/
# DEBUG:__main__:Exctracting features from https://nypost.com/2018/07/28/longest-lunar-eclipse-of-century-was-visible-everywhere-but-us/
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:
#
#  PROCESSING PAGE: https://nypost.com/news/page/6
#
#               ====================================
#
#
# DEBUG:__main__:Processing url: https://nypost.com/2018/07/28/cops-fired-in-fake-american-beatdown-of-hispanic-man/
# DEBUG:__main__:Exctracting features from https://nypost.com/2018/07/28/cops-fired-in-fake-american-beatdown-of-hispanic-man/
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://nypost.com/2018/07/28/spain-says-hundreds-of-african-migrants-rescued-in-two-days/
# DEBUG:__main__:Exctracting features from https://nypost.com/2018/07/28/spain-says-hundreds-of-african-migrants-rescued-in-two-days/
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://nypost.com/2018/07/28/doctor-gets-10-years-in-prison-for-sexually-assaulting-patients/
# DEBUG:__main__:Exctracting features from https://nypost.com/2018/07/28/doctor-gets-10-years-in-prison-for-sexually-assaulting-patients/
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://nypost.com/2018/07/28/egypt-court-sentences-75-to-death-for-2013-sit-in/
# DEBUG:__main__:Exctracting features from https://nypost.com/2018/07/28/egypt-court-sentences-75-to-death-for-2013-sit-in/
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://nypost.com/2018/07/28/theodore-mccarrick-resigns-from-college-of-cardinals-over-alleged-sexual-abuse/
# DEBUG:__main__:Exctracting features from https://nypost.com/2018/07/28/theodore-mccarrick-resigns-from-college-of-cardinals-over-alleged-sexual-abuse/
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://nypost.com/2018/07/28/taliban-claims-to-have-discussed-peace-talks-with-a-us-official/
# DEBUG:__main__:Exctracting features from https://nypost.com/2018/07/28/taliban-claims-to-have-discussed-peace-talks-with-a-us-official/
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://nypost.com/2018/07/28/five-dead-including-three-at-nursing-home-in-apparent-shooting-spree/
# DEBUG:__main__:Exctracting features from https://nypost.com/2018/07/28/five-dead-including-three-at-nursing-home-in-apparent-shooting-spree/
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://nypost.com/2018/07/27/recordings-show-change-in-weather-before-tourist-boat-sank/
# DEBUG:__main__:Exctracting features from https://nypost.com/2018/07/27/recordings-show-change-in-weather-before-tourist-boat-sank/
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://nypost.com/2018/07/27/ocasio-cortez-hits-the-campaign-trail-for-other-dems/
# DEBUG:__main__:Exctracting features from https://nypost.com/2018/07/27/ocasio-cortez-hits-the-campaign-trail-for-other-dems/
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://nypost.com/2018/07/27/officials-say-north-korea-returning-remains-shows-improved-relations/
# DEBUG:__main__:Exctracting features from https://nypost.com/2018/07/27/officials-say-north-korea-returning-remains-shows-improved-relations/
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:
#
#  PROCESSING PAGE: https://nypost.com/news/page/7
#
#               ====================================
#
#
# DEBUG:__main__:Processing url: https://nypost.com/2018/07/27/trump-celebrates-roaring-economy-as-experts-urge-caution/
# DEBUG:__main__:Exctracting features from https://nypost.com/2018/07/27/trump-celebrates-roaring-economy-as-experts-urge-caution/
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://nypost.com/2018/07/27/fierce-winds-spark-firenadoes-in-california/
# DEBUG:__main__:Exctracting features from https://nypost.com/2018/07/27/fierce-winds-spark-firenadoes-in-california/
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://nypost.com/2018/07/27/trump-will-campaign-6-or-7-days-a-week-for-gop-candidates/
# DEBUG:__main__:Exctracting features from https://nypost.com/2018/07/27/trump-will-campaign-6-or-7-days-a-week-for-gop-candidates/
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://nypost.com/2018/07/27/brawl-breaks-out-at-trumps-new-walk-of-fame-star/
# DEBUG:__main__:Exctracting features from https://nypost.com/2018/07/27/brawl-breaks-out-at-trumps-new-walk-of-fame-star/
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://nypost.com/2018/07/27/heroic-nursing-student-wounded-trying-to-help-toronto-shooting-victims/
# DEBUG:__main__:Exctracting features from https://nypost.com/2018/07/27/heroic-nursing-student-wounded-trying-to-help-toronto-shooting-victims/
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://nypost.com/2018/07/27/family-forced-autistic-relative-to-eat-her-moms-ashes-feds/
# DEBUG:__main__:Exctracting features from https://nypost.com/2018/07/27/family-forced-autistic-relative-to-eat-her-moms-ashes-feds/
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://nypost.com/2018/07/27/elizabeth-smart-tried-to-save-india-oxenberg-from-sex-cult/
# DEBUG:__main__:Exctracting features from https://nypost.com/2018/07/27/elizabeth-smart-tried-to-save-india-oxenberg-from-sex-cult/
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://nypost.com/2018/07/27/inmates-steal-nearly-225k-by-hacking-jail-issued-tablets/
# DEBUG:__main__:Exctracting features from https://nypost.com/2018/07/27/inmates-steal-nearly-225k-by-hacking-jail-issued-tablets/
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://nypost.com/2018/07/27/iranian-general-answers-trumps-all-caps-tweet-we-are-ready/
# DEBUG:__main__:Exctracting features from https://nypost.com/2018/07/27/iranian-general-answers-trumps-all-caps-tweet-we-are-ready/
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://nypost.com/2018/07/27/global-superpowers-scrabbling-to-claim-north-poles-new-ocean/
# DEBUG:__main__:Exctracting features from https://nypost.com/2018/07/27/global-superpowers-scrabbling-to-claim-north-poles-new-ocean/
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:
#
#  PROCESSING PAGE: https://nypost.com/news/page/8
#
#               ====================================
#
#
# DEBUG:__main__:Processing url: https://nypost.com/2018/07/27/video-shows-cop-threatening-to-send-boy-to-f-ing-hospital/
# DEBUG:__main__:Exctracting features from https://nypost.com/2018/07/27/video-shows-cop-threatening-to-send-boy-to-f-ing-hospital/
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://nypost.com/2018/07/27/turkish-woman-held-by-israel-is-free-thanks-to-trump-deal/
# DEBUG:__main__:Exctracting features from https://nypost.com/2018/07/27/turkish-woman-held-by-israel-is-free-thanks-to-trump-deal/
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://nypost.com/2018/07/27/facebook-blocks-alex-jones-for-30-days/
# DEBUG:__main__:Exctracting features from https://nypost.com/2018/07/27/facebook-blocks-alex-jones-for-30-days/
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://nypost.com/2018/07/27/french-gangster-who-escaped-prison-in-helicopter-spotted-near-paris/
# DEBUG:__main__:Exctracting features from https://nypost.com/2018/07/27/french-gangster-who-escaped-prison-in-helicopter-spotted-near-paris/
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://nypost.com/2018/07/27/mcdonalds-worker-says-woman-was-talking-a-lot-of-smack-before-beatdown/
# DEBUG:__main__:Exctracting features from https://nypost.com/2018/07/27/mcdonalds-worker-says-woman-was-talking-a-lot-of-smack-before-beatdown/
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://nypost.com/2018/07/27/teen-busted-for-breaking-into-home-for-wi-fi/
# DEBUG:__main__:Exctracting features from https://nypost.com/2018/07/27/teen-busted-for-breaking-into-home-for-wi-fi/
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://nypost.com/2018/07/27/colombian-cartel-puts-70k-bounty-on-drug-sniffing-dog/
# DEBUG:__main__:Exctracting features from https://nypost.com/2018/07/27/colombian-cartel-puts-70k-bounty-on-drug-sniffing-dog/
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://nypost.com/2018/07/27/school-chief-resigns-after-being-outed-as-high-school-pooper/
# DEBUG:__main__:Exctracting features from https://nypost.com/2018/07/27/school-chief-resigns-after-being-outed-as-high-school-pooper/
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://nypost.com/2018/07/27/trump-says-surge-in-economic-growth-rate-not-a-one-time-shot/
# DEBUG:__main__:Exctracting features from https://nypost.com/2018/07/27/trump-says-surge-in-economic-growth-rate-not-a-one-time-shot/
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://nypost.com/2018/07/27/putin-invites-trump-to-moscow/
# DEBUG:__main__:Exctracting features from https://nypost.com/2018/07/27/putin-invites-trump-to-moscow/
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:
#
#  PROCESSING PAGE: https://nypost.com/news/page/9
#
#               ====================================
#
#
# DEBUG:__main__:Processing url: https://nypost.com/2018/07/27/ex-teacher-cleared-on-charges-of-sex-with-student/
# DEBUG:__main__:Exctracting features from https://nypost.com/2018/07/27/ex-teacher-cleared-on-charges-of-sex-with-student/
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://nypost.com/2018/07/27/incredible-discovery-sheds-light-on-europes-lost-people/
# DEBUG:__main__:Exctracting features from https://nypost.com/2018/07/27/incredible-discovery-sheds-light-on-europes-lost-people/
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://nypost.com/2018/07/27/woman-punched-by-cop-on-beach-rejects-plea-offer/
# DEBUG:__main__:Exctracting features from https://nypost.com/2018/07/27/woman-punched-by-cop-on-beach-rejects-plea-offer/
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://nypost.com/2018/07/27/rancid-smell-of-dirty-socks-diverts-spirit-flight/
# DEBUG:__main__:Exctracting features from https://nypost.com/2018/07/27/rancid-smell-of-dirty-socks-diverts-spirit-flight/
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://nypost.com/2018/07/27/trump-cheers-jerry-jones-for-dallas-cowboys-anthem-policy/
# DEBUG:__main__:Exctracting features from https://nypost.com/2018/07/27/trump-cheers-jerry-jones-for-dallas-cowboys-anthem-policy/
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://nypost.com/2018/07/27/palestinian-teen-killed-at-scene-after-stabbing-israelis-in-settlement/
# DEBUG:__main__:Exctracting features from https://nypost.com/2018/07/27/palestinian-teen-killed-at-scene-after-stabbing-israelis-in-settlement/
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://nypost.com/2018/07/27/california-wildfire-turns-deadly/
# DEBUG:__main__:Exctracting features from https://nypost.com/2018/07/27/california-wildfire-turns-deadly/
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://nypost.com/2018/07/27/alaska-airlines-pilot-gets-prison-for-flying-while-intoxicated/
# DEBUG:__main__:Exctracting features from https://nypost.com/2018/07/27/alaska-airlines-pilot-gets-prison-for-flying-while-intoxicated/
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://nypost.com/2018/07/27/flight-attendants-save-apparent-human-trafficking-victims/
# DEBUG:__main__:Exctracting features from https://nypost.com/2018/07/27/flight-attendants-save-apparent-human-trafficking-victims/
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://nypost.com/2018/07/27/trump-denies-approving-2016-meeting-with-russians/
# DEBUG:__main__:Exctracting features from https://nypost.com/2018/07/27/trump-denies-approving-2016-meeting-with-russians/
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:
#
#  PROCESSING PAGE: https://nypost.com/news/page/10
#
#               ====================================
#
#
# DEBUG:__main__:Processing url: https://nypost.com/2018/07/27/georgia-police-officers-fired-for-coin-flip-arrest/
# DEBUG:__main__:Exctracting features from https://nypost.com/2018/07/27/georgia-police-officers-fired-for-coin-flip-arrest/
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://nypost.com/2018/07/27/california-wildfires-cause-injuries-continue-to-torch-homes/
# DEBUG:__main__:Exctracting features from https://nypost.com/2018/07/27/california-wildfires-cause-injuries-continue-to-torch-homes/
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://nypost.com/2018/07/27/stormy-daniels-lawyer-says-trump-paid-3-more-women-hush-money/
# DEBUG:__main__:Exctracting features from https://nypost.com/2018/07/27/stormy-daniels-lawyer-says-trump-paid-3-more-women-hush-money/
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://nypost.com/2018/07/27/tribal-land-near-grand-canyon-suffers-extensive-flood-damage/
# DEBUG:__main__:Exctracting features from https://nypost.com/2018/07/27/tribal-land-near-grand-canyon-suffers-extensive-flood-damage/
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://nypost.com/2018/07/26/feds-will-meet-midnight-deadline-to-reunite-immigrant-kids-with-eligible-parents/
# DEBUG:__main__:Exctracting features from https://nypost.com/2018/07/26/feds-will-meet-midnight-deadline-to-reunite-immigrant-kids-with-eligible-parents/
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://nypost.com/2018/07/26/trump-takes-credit-for-illinois-steel-mill-expansion/
# DEBUG:__main__:Exctracting features from https://nypost.com/2018/07/26/trump-takes-credit-for-illinois-steel-mill-expansion/
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://nypost.com/2018/07/26/man-stole-ambulance-from-hospital-because-it-was-too-hot-to-walk-cops/
# DEBUG:__main__:Exctracting features from https://nypost.com/2018/07/26/man-stole-ambulance-from-hospital-because-it-was-too-hot-to-walk-cops/
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://nypost.com/2018/07/26/mom-let-2-year-old-starve-to-death-while-dancing-for-money-at-club/
# DEBUG:__main__:Exctracting features from https://nypost.com/2018/07/26/mom-let-2-year-old-starve-to-death-while-dancing-for-money-at-club/
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://nypost.com/2018/07/26/north-korea-returns-remains-of-soldiers-missing-since-korean-war/
# DEBUG:__main__:Exctracting features from https://nypost.com/2018/07/26/north-korea-returns-remains-of-soldiers-missing-since-korean-war/
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://nypost.com/2018/07/26/fugitive-couple-found-after-nearly-2-decades-on-the-run/
# DEBUG:__main__:Exctracting features from https://nypost.com/2018/07/26/fugitive-couple-found-after-nearly-2-decades-on-the-run/
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:
#
#  PROCESSING PAGE: https://nypost.com/news/page/11
#
#               ====================================
#
#
# DEBUG:__main__:Processing url: https://nypost.com/2018/07/26/mom-left-baby-in-hot-car-to-drink-on-national-tequila-day-police/
# DEBUG:__main__:Exctracting features from https://nypost.com/2018/07/26/mom-left-baby-in-hot-car-to-drink-on-national-tequila-day-police/
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://nypost.com/2018/07/26/russians-targeted-dem-senator-as-trump-said-to-vote-her-out/
# DEBUG:__main__:Exctracting features from https://nypost.com/2018/07/26/russians-targeted-dem-senator-as-trump-said-to-vote-her-out/
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://nypost.com/2018/07/26/journalist-claims-airline-kicked-her-disabled-son-off-flight/
# DEBUG:__main__:Exctracting features from https://nypost.com/2018/07/26/journalist-claims-airline-kicked-her-disabled-son-off-flight/
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://nypost.com/2018/07/26/cohen-trump-approved-2016-trump-tower-meeting-with-russians/
# DEBUG:__main__:Exctracting features from https://nypost.com/2018/07/26/cohen-trump-approved-2016-trump-tower-meeting-with-russians/
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://nypost.com/2018/07/26/yoga-pants-thieves-seen-on-video-robbing-lululemon-stores/
# DEBUG:__main__:Exctracting features from https://nypost.com/2018/07/26/yoga-pants-thieves-seen-on-video-robbing-lululemon-stores/
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://nypost.com/2018/07/26/inmate-seen-trying-to-escape-atop-moving-patrol-car/
# DEBUG:__main__:Exctracting features from https://nypost.com/2018/07/26/inmate-seen-trying-to-escape-atop-moving-patrol-car/
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://nypost.com/2018/07/26/abused-children-whipped-kept-in-dungeon-like-room-police/
# DEBUG:__main__:Exctracting features from https://nypost.com/2018/07/26/abused-children-whipped-kept-in-dungeon-like-room-police/
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://nypost.com/2018/07/26/man-accused-of-dragging-fbi-agent-with-truck-to-evade-arrest/
# DEBUG:__main__:Exctracting features from https://nypost.com/2018/07/26/man-accused-of-dragging-fbi-agent-with-truck-to-evade-arrest/
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://nypost.com/2018/07/26/elderly-man-accused-of-shooting-at-assisted-living-worker-cops/
# DEBUG:__main__:Exctracting features from https://nypost.com/2018/07/26/elderly-man-accused-of-shooting-at-assisted-living-worker-cops/
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://nypost.com/2018/07/26/mom-arrested-in-babys-death-after-reporting-abduction/
# DEBUG:__main__:Exctracting features from https://nypost.com/2018/07/26/mom-arrested-in-babys-death-after-reporting-abduction/
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:
#
#  PROCESSING PAGE: https://nypost.com/news/page/12
#
#               ====================================
#
#
# DEBUG:__main__:Processing url: https://nypost.com/2018/07/26/black-woman-says-wells-fargo-refused-to-cash-check-called-cops/
# DEBUG:__main__:Exctracting features from https://nypost.com/2018/07/26/black-woman-says-wells-fargo-refused-to-cash-check-called-cops/
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://nypost.com/2018/07/26/teen-couple-plotted-to-kill-parents-who-wouldnt-allow-them-to-marry-cops/
# DEBUG:__main__:Exctracting features from https://nypost.com/2018/07/26/teen-couple-plotted-to-kill-parents-who-wouldnt-allow-them-to-marry-cops/
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://nypost.com/2018/07/26/former-disney-star-takes-stage-on-trumps-behalf/
# DEBUG:__main__:Exctracting features from https://nypost.com/2018/07/26/former-disney-star-takes-stage-on-trumps-behalf/
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://nypost.com/2018/07/26/inn-employee-charged-with-allegedly-killing-co-worker-on-hike/
# DEBUG:__main__:Exctracting features from https://nypost.com/2018/07/26/inn-employee-charged-with-allegedly-killing-co-worker-on-hike/
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://nypost.com/2018/07/26/man-injured-dies-after-meeting-with-internet-date/
# DEBUG:__main__:Exctracting features from https://nypost.com/2018/07/26/man-injured-dies-after-meeting-with-internet-date/
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://nypost.com/2018/07/26/surfer-dies-after-being-found-face-down-during-huge-swell/
# DEBUG:__main__:Exctracting features from https://nypost.com/2018/07/26/surfer-dies-after-being-found-face-down-during-huge-swell/
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://nypost.com/2018/07/26/teen-found-safe-man-arrested-after-reported-abduction/
# DEBUG:__main__:Exctracting features from https://nypost.com/2018/07/26/teen-found-safe-man-arrested-after-reported-abduction/
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://nypost.com/2018/07/26/woman-poisoned-baby-in-twisted-plot-to-get-husband-back-cops/
# DEBUG:__main__:Exctracting features from https://nypost.com/2018/07/26/woman-poisoned-baby-in-twisted-plot-to-get-husband-back-cops/
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://nypost.com/2018/07/26/gunmen-kill-6-people-at-funeral/
# DEBUG:__main__:Exctracting features from https://nypost.com/2018/07/26/gunmen-kill-6-people-at-funeral/
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://nypost.com/2018/07/26/library-staff-stole-millions-in-rare-books-over-decades-prosecutors/
# DEBUG:__main__:Exctracting features from https://nypost.com/2018/07/26/library-staff-stole-millions-in-rare-books-over-decades-prosecutors/
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:
#
#  PROCESSING PAGE: https://nypost.com/news/page/13
#
#               ====================================
#
#
# DEBUG:__main__:Processing url: https://nypost.com/2018/07/26/family-finds-grandpas-entire-casket-unearthed-upside-down/
# DEBUG:__main__:Exctracting features from https://nypost.com/2018/07/26/family-finds-grandpas-entire-casket-unearthed-upside-down/
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://nypost.com/2018/07/26/man-jumps-on-roof-of-wifes-car-fatally-shoots-her-cops/
# DEBUG:__main__:Exctracting features from https://nypost.com/2018/07/26/man-jumps-on-roof-of-wifes-car-fatally-shoots-her-cops/
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://nypost.com/2018/07/26/trash-couple-accused-of-locking-up-children-in-basement/
# DEBUG:__main__:Exctracting features from https://nypost.com/2018/07/26/trash-couple-accused-of-locking-up-children-in-basement/
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://nypost.com/2018/07/26/minister-compares-burning-diseased-pigs-to-auschwitz/
# DEBUG:__main__:Exctracting features from https://nypost.com/2018/07/26/minister-compares-burning-diseased-pigs-to-auschwitz/
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://nypost.com/2018/07/26/slain-butchers-coworker-charged-with-murder/
# DEBUG:__main__:Exctracting features from https://nypost.com/2018/07/26/slain-butchers-coworker-charged-with-murder/
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://nypost.com/2018/07/26/trump-vows-to-sanction-turkey-if-they-dont-release-us-pastor/
# DEBUG:__main__:Exctracting features from https://nypost.com/2018/07/26/trump-vows-to-sanction-turkey-if-they-dont-release-us-pastor/
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://nypost.com/2018/07/26/sessions-says-he-missed-opportunity-in-lock-her-up-chant/
# DEBUG:__main__:Exctracting features from https://nypost.com/2018/07/26/sessions-says-he-missed-opportunity-in-lock-her-up-chant/
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://nypost.com/2018/07/26/missing-college-students-brothers-boyfriend-cleared-of-suspicion/
# DEBUG:__main__:Exctracting features from https://nypost.com/2018/07/26/missing-college-students-brothers-boyfriend-cleared-of-suspicion/
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://nypost.com/2018/07/26/hundreds-of-sea-turtles-washing-up-on-beaches-in-mass-mortality-event/
# DEBUG:__main__:Exctracting features from https://nypost.com/2018/07/26/hundreds-of-sea-turtles-washing-up-on-beaches-in-mass-mortality-event/
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://nypost.com/2018/07/26/toronto-gunman-got-weapon-from-gang-related-source-in-us/
# DEBUG:__main__:Exctracting features from https://nypost.com/2018/07/26/toronto-gunman-got-weapon-from-gang-related-source-in-us/
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:
#
#  PROCESSING PAGE: https://nypost.com/news/page/14
#
#               ====================================
#
#
# DEBUG:__main__:Processing url: https://nypost.com/2018/07/26/uk-prepares-for-furnace-friday-as-record-heat-wave-continues/
# DEBUG:__main__:Exctracting features from https://nypost.com/2018/07/26/uk-prepares-for-furnace-friday-as-record-heat-wave-continues/
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://nypost.com/2018/07/26/teen-set-up-date-with-man-on-instagram-then-robbed-him-police/
# DEBUG:__main__:Exctracting features from https://nypost.com/2018/07/26/teen-set-up-date-with-man-on-instagram-then-robbed-him-police/
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://nypost.com/2018/07/26/bay-area-sees-spike-in-violent-crime-on-its-transit-system/
# DEBUG:__main__:Exctracting features from https://nypost.com/2018/07/26/bay-area-sees-spike-in-violent-crime-on-its-transit-system/

# %%
FIX AUTHORS
# Out:
# True

# %%
# %load_ext autoreload
# %autoreload 2

# For debugging turn on logging to console
import logging
logging.basicConfig(level=logging.DEBUG)
log = logging.getLogger(__name__)
logging.getLogger('urllib3').setLevel(logging.WARNING)


# mongodb
import pymongo as pm

# fine-tuned newspaper lib
from resources.newspaper import newspaper
from resources.newspaper.newspaper.source import Source
from resources.newspaper.newspaper.article import Article

import bs4 as bs
from urllib.parse import urljoin
from dateutil.parser import parse as date_parser
from time import sleep
import random
import pytz
from datetime import datetime, timedelta

import requests

# %%
# Initialize PyMongo to work with MongoDBs
conn = 'mongodb://localhost:27017'
client = pm.MongoClient(conn, maxPoolSize=200)

# define db 
# DB_NAME = 'scrape'
DB_NAME = 'FINALP'
db = client[DB_NAME]

def saveToDB(db, collection, url, html, meta={}):
    """
    Saves a document to mongoDB, making sure there are no duplicates by 
    'url' value
    
    Parameters:
    --------
    db, collection  : mongo db connection
    url, html, meta : values to store
    
    Returns:
    --------
    Saved document
    """
    collection = db[collection]
    collection.update_one(
        {'url' : url},
        {
            '$set':
                {'url' : url,
                 'html' : html,
                 'meta' : meta
                }
        }
        ,
        upsert=True
    )
    log.debug(f'Saved to DB')

def scrape(url, db, collection):
    '''
    Scrapes an article from the 'url' up to the 'latest_date'
    
    Parameters:
    --------
    url         : main news website url
    date        : YYYY-MM-DD
    db          : database name
    collection  : mongodb collection
    
    Returns:
    --------
    Article's html and features stored to db, 
    Article's publish date
    
    '''
    log.debug(f"Exctracting features from {url}")
    try:
        article = Article(url)
        article.download()
        # the below method may only extract a snippet... 
        # check the database for results of text extraction
        # and apply additional processing if needed after 
        # article has been stored in the DB
        # see code below Newrepublic for example
        article.parse()
    except Exception as e:
        log.critical(f'Data not saved: {e}')
        return datetime.datetime.now()
    
    saveToDB(db, collection, article.url, article.html, meta={
        'date'    :article.publish_date,
        'title'   :article.title,
        'text'    :article.text,
        'authors' :article.authors
    })
    
    return article.publish_date

def addToDB(DB_NAME,COL_NAME,PATH,FILE):
    '''
    Imports a file into mongoDB
    
    Parameters:
    --------
    DB_NAME : Name of the database to connect to
    COL_NAME: Name of the collection to create
    PATH    : Path to folder with the file
    FILE  : Filename
    
    Returns:
    --------
    Collection COL_NAME in DB_NAME database
    '''
    # !mongoimport --db {DB_NAME} --collection {COL_NAME} --file {PATH+FILE} --batchSize 1
    print(f'Collection {COL_NAME} in {DB_NAME} database created')

# %%
collection = 'huffpost'
source = 'https://www.huffingtonpost.com/archive/'
earliest_date = date_parser('2017-01-01')
latest_date = date_parser('2017-03-15')
stopWords = ['HEALTHY LIVING',
            'ENTERTAINMENT',
            'STYLE',
            'COMEDY',
            'WEDDINGS',
            'SPORTS',
            'ARTS & CULTURE',
            'TASTE',
            'PARENTS',
            'BOOKS',
            'HUFFPOST PERSONAL',
            'QUEER VOICES']

base_url = 'https://www.huffingtonpost.com/'
date = 1

while True:
    date_to_scrape = str(latest_date-timedelta(date))[:10]
    log.debug(f"==================\n Processing DATE {date_to_scrape}\n URL: {source+date_to_scrape}")
    s = Source(source+date_to_scrape)
    date += 1
    s.download()
    soup = bs.BeautifulSoup(s.html,'lxml')
    for div in soup.findAll('div', {'class':'card__details'}):
        try:
            category = div.span.text
            if category not in stopWords:
                for a in div.findAll('a',{'class':'card__link yr-card-headline'}):
                    try:
                        url = urljoin(base_url, a['href'])
                        log.debug(f"Processing url: {url}")
                        article_date = scrape(url, db, collection)
                    except Exception as e:
                        log.debug(e)
            else:
                log.debug(f'Skipping category {category}')
        except Exception as e:
            log.debug(e)
    
    if (latest_date-timedelta(date)) <= earliest_date:
        log.debug(f"Finished. Last date scraped: {latest_date-timedelta(date)}")
        break
# Out:
# DEBUG:__main__:==================
#  Processing DATE 2017-03-20
#  URL: https://www.huffingtonpost.com/archive/2017-03-20
# DEBUG:__main__:Skipping category ENTERTAINMENT
# DEBUG:__main__:Processing url: https://www.huffingtonpost.com/entry/house-intelligence-committee-gop-leaks-russia-trump_us_58d019b8e4b00705db518886
# DEBUG:__main__:Exctracting features from https://www.huffingtonpost.com/entry/house-intelligence-committee-gop-leaks-russia-trump_us_58d019b8e4b00705db518886
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://www.huffingtonpost.com/entry/african-visas-denied_us_58d04590e4b0be71dcf74bd6
# DEBUG:__main__:Exctracting features from https://www.huffingtonpost.com/entry/african-visas-denied_us_58d04590e4b0be71dcf74bd6
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://www.huffingtonpost.com/entry/peru-flooding_us_58d0309ee4b00705db51cae9
# DEBUG:__main__:Exctracting features from https://www.huffingtonpost.com/entry/peru-flooding_us_58d0309ee4b00705db51cae9
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://www.huffingtonpost.com/entry/article-50-brexit-may_us_58cfbeb3e4b0be71dcf60072
# DEBUG:__main__:Exctracting features from https://www.huffingtonpost.com/entry/article-50-brexit-may_us_58cfbeb3e4b0be71dcf60072
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Skipping category ENTERTAINMENT
# DEBUG:__main__:Skipping category QUEER VOICES
# DEBUG:__main__:Processing url: https://www.huffingtonpost.com/entry/donald-trump-germany-military_us_58cf4155e4b0ec9d29dcfcb4
# DEBUG:__main__:Exctracting features from https://www.huffingtonpost.com/entry/donald-trump-germany-military_us_58cf4155e4b0ec9d29dcfcb4
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://www.huffingtonpost.com/entry/trump-wiretap-lies-ambassador_us_58cf3314e4b00705db505faf
# DEBUG:__main__:Exctracting features from https://www.huffingtonpost.com/entry/trump-wiretap-lies-ambassador_us_58cf3314e4b00705db505faf
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://www.huffingtonpost.com/entry/trump-camp-russian-collution_us_58cf1551e4b0ec9d29dcf167
# DEBUG:__main__:Exctracting features from https://www.huffingtonpost.com/entry/trump-camp-russian-collution_us_58cf1551e4b0ec9d29dcf167
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://www.huffingtonpost.com/entry/trump-obama-wiretap_us_58d018ade4b0be71dcf6d96a
# DEBUG:__main__:Exctracting features from https://www.huffingtonpost.com/entry/trump-obama-wiretap_us_58d018ade4b0be71dcf6d96a
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://www.huffingtonpost.com/entry/us-muslim-teen-flight_us_58d01897e4b0be71dcf6d952
# DEBUG:__main__:Exctracting features from https://www.huffingtonpost.com/entry/us-muslim-teen-flight_us_58d01897e4b0be71dcf6d952
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://www.huffingtonpost.com/entry/jim-himes-donald-trump-twitter_us_58cffce0e4b00705db511951
# DEBUG:__main__:Exctracting features from https://www.huffingtonpost.com/entry/jim-himes-donald-trump-twitter_us_58cffce0e4b00705db511951
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Skipping category HEALTHY LIVING
# DEBUG:__main__:Processing url: https://www.huffingtonpost.com/entry/trump-sanctuary-cities_us_58d006e7e4b0be71dcf69233
# DEBUG:__main__:Exctracting features from https://www.huffingtonpost.com/entry/trump-sanctuary-cities_us_58d006e7e4b0be71dcf69233
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://www.huffingtonpost.com/entry/poor-minority-neighborhoods-have-more-tobacco-selling-shops-per-capita_us_58d049ade4b0be71dcf7509c
# DEBUG:__main__:Exctracting features from https://www.huffingtonpost.com/entry/poor-minority-neighborhoods-have-more-tobacco-selling-shops-per-capita_us_58d049ade4b0be71dcf7509c
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Skipping category HEALTHY LIVING
# DEBUG:__main__:Processing url: https://www.huffingtonpost.com/entry/mondays-morning-email-what-to-expect-in-the-supreme-court-confirmation-hearing-today_us_58cfb2a2e4b00705db509af9
# DEBUG:__main__:Exctracting features from https://www.huffingtonpost.com/entry/mondays-morning-email-what-to-expect-in-the-supreme-court-confirmation-hearing-today_us_58cfb2a2e4b00705db509af9
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://www.huffingtonpost.com/entry/huffpost-hill-trump-probably-not-joining-next-lock-her-up-chant_us_58d0477fe4b00705db51fbf6
# DEBUG:__main__:Exctracting features from https://www.huffingtonpost.com/entry/huffpost-hill-trump-probably-not-joining-next-lock-her-up-chant_us_58d0477fe4b00705db51fbf6
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://www.huffingtonpost.com/entry/huffpost-headline-quiz-mar-13-to-mar-19_us_58cea89fe4b00705db50302f
# DEBUG:__main__:Exctracting features from https://www.huffingtonpost.com/entry/huffpost-headline-quiz-mar-13-to-mar-19_us_58cea89fe4b00705db50302f
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://www.huffingtonpost.com/entry/some-genius-transformed-your-favorite-memes-into-fine-art_us_58d00711e4b00705db5143a5
# DEBUG:__main__:Exctracting features from https://www.huffingtonpost.com/entry/some-genius-transformed-your-favorite-memes-into-fine-art_us_58d00711e4b00705db5143a5
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Skipping category ARTS & CULTURE
# DEBUG:__main__:Skipping category COMEDY
# DEBUG:__main__:Skipping category HEALTHY LIVING
# DEBUG:__main__:Skipping category ENTERTAINMENT
# DEBUG:__main__:Processing url: https://www.huffingtonpost.com/entry/neil-gorsuch-working-women_us_58cff5afe4b0ec9d29dd9e93
# DEBUG:__main__:Exctracting features from https://www.huffingtonpost.com/entry/neil-gorsuch-working-women_us_58cff5afe4b0ec9d29dd9e93
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://www.huffingtonpost.com/entry/ed-sheerans-zion-lennox-shape-of-you-latin-remix_us_58d03b09e4b0be71dcf72c6f
# DEBUG:__main__:Exctracting features from https://www.huffingtonpost.com/entry/ed-sheerans-zion-lennox-shape-of-you-latin-remix_us_58d03b09e4b0be71dcf72c6f
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Skipping category COMEDY
# DEBUG:__main__:Skipping category SPORTS
# DEBUG:__main__:Processing url: https://www.huffingtonpost.com/entry/short-film-explores-what-its-like-to-find-out-you-have-an-sti_us_58cff9fce4b0ec9d29ddaa56
# DEBUG:__main__:Exctracting features from https://www.huffingtonpost.com/entry/short-film-explores-what-its-like-to-find-out-you-have-an-sti_us_58cff9fce4b0ec9d29ddaa56
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://www.huffingtonpost.com/entry/neil-gorsuch-supreme-court-senate-judiciary-committee_us_58cfe06de4b0be71dcf62abd
# DEBUG:__main__:Exctracting features from https://www.huffingtonpost.com/entry/neil-gorsuch-supreme-court-senate-judiciary-committee_us_58cfe06de4b0be71dcf62abd
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Skipping category COMEDY
# DEBUG:__main__:Skipping category PARENTS
# DEBUG:__main__:Skipping category ENTERTAINMENT
# DEBUG:__main__:Processing url: https://www.huffingtonpost.com/entry/man-filmed-his-shooting-death_us_58cfcc8de4b00705db50bffd
# DEBUG:__main__:Exctracting features from https://www.huffingtonpost.com/entry/man-filmed-his-shooting-death_us_58cfcc8de4b00705db50bffd
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://www.huffingtonpost.com/entry/taraji-p-henson-wants-to-play-a-marvel-superhero-someone-make-this-happen_us_58cfdd32e4b00705db50d4b7
# DEBUG:__main__:Exctracting features from https://www.huffingtonpost.com/entry/taraji-p-henson-wants-to-play-a-marvel-superhero-someone-make-this-happen_us_58cfdd32e4b00705db50d4b7
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://www.huffingtonpost.com/entry/stephen-hawking-piers-morgans-gender-equality_us_58cfc7afe4b0ec9d29dd537b
# DEBUG:__main__:Exctracting features from https://www.huffingtonpost.com/entry/stephen-hawking-piers-morgans-gender-equality_us_58cfc7afe4b0ec9d29dd537b
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Skipping category QUEER VOICES
# DEBUG:__main__:Processing url: https://www.huffingtonpost.com/entry/less-than-a-quarter-of-the-public-thinks-donald-trump-is-respected-by-other-leaders_us_58d038fae4b0ec9d29de7aba
# DEBUG:__main__:Exctracting features from https://www.huffingtonpost.com/entry/less-than-a-quarter-of-the-public-thinks-donald-trump-is-respected-by-other-leaders_us_58d038fae4b0ec9d29de7aba
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Skipping category TASTE
# DEBUG:__main__:Processing url: https://www.huffingtonpost.com/entry/jessica-chastain-shuts-down-bro-who-tried-to-mansplain-womens-health_us_58cfdfb2e4b0be71dcf629a9
# DEBUG:__main__:Exctracting features from https://www.huffingtonpost.com/entry/jessica-chastain-shuts-down-bro-who-tried-to-mansplain-womens-health_us_58cfdfb2e4b0be71dcf629a9
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://www.huffingtonpost.com/entry/stephen-hawking-donald-trump_us_58d016cee4b00705db51828d
# DEBUG:__main__:Exctracting features from https://www.huffingtonpost.com/entry/stephen-hawking-donald-trump_us_58d016cee4b00705db51828d
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://www.huffingtonpost.com/entry/catchy-schoolhouse-rock-parody-reminds-us-that-plan-b-is-just-a-pill_us_58cfdda4e4b00705db50d69f
# DEBUG:__main__:Exctracting features from https://www.huffingtonpost.com/entry/catchy-schoolhouse-rock-parody-reminds-us-that-plan-b-is-just-a-pill_us_58cfdda4e4b00705db50d69f
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://www.huffingtonpost.com/entry/cinco-de-mayo-celebration-canceled-immigration-ice_us_58cfed84e4b0be71dcf6431e
# DEBUG:__main__:Exctracting features from https://www.huffingtonpost.com/entry/cinco-de-mayo-celebration-canceled-immigration-ice_us_58cfed84e4b0be71dcf6431e
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://www.huffingtonpost.com/entry/james-comey-fbi-trump-wiretap_us_58cc476ce4b0be71dcf4d3d6
# DEBUG:__main__:Exctracting features from https://www.huffingtonpost.com/entry/james-comey-fbi-trump-wiretap_us_58cc476ce4b0be71dcf4d3d6
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://www.huffingtonpost.com/entry/trump-russia-comey_us_58d01dd6e4b0be71dcf6e972
# DEBUG:__main__:Exctracting features from https://www.huffingtonpost.com/entry/trump-russia-comey_us_58d01dd6e4b0be71dcf6e972
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://www.huffingtonpost.com/entry/trumps-supreme-court-nominee-neil-gorsuch-to-face-senators-in-marathon-hearing_us_58cfe137e4b0ec9d29dd742c
# DEBUG:__main__:Exctracting features from https://www.huffingtonpost.com/entry/trumps-supreme-court-nominee-neil-gorsuch-to-face-senators-in-marathon-hearing_us_58cfe137e4b0ec9d29dd742c
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Skipping category WEDDINGS
# DEBUG:__main__:Skipping category QUEER VOICES
# DEBUG:__main__:Skipping category QUEER VOICES
# DEBUG:__main__:Processing url: https://www.huffingtonpost.com/entry/comey-trump-tweets_us_58cff4c5e4b0be71dcf65283
# DEBUG:__main__:Exctracting features from https://www.huffingtonpost.com/entry/comey-trump-tweets_us_58cff4c5e4b0be71dcf65283
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Skipping category COMEDY
# DEBUG:__main__:Processing url: https://www.huffingtonpost.com/entry/laptops-electronics-ban-flights_us_58d04b51e4b0ec9d29dea4de
# DEBUG:__main__:Exctracting features from https://www.huffingtonpost.com/entry/laptops-electronics-ban-flights_us_58d04b51e4b0ec9d29dea4de
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://www.huffingtonpost.com/entry/tad-cummins-elizabeth-thomas-manhunt_us_58d036e2e4b00705db51d599
# DEBUG:__main__:Exctracting features from https://www.huffingtonpost.com/entry/tad-cummins-elizabeth-thomas-manhunt_us_58d036e2e4b00705db51d599
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://www.huffingtonpost.com/entry/teen-crocodile-water_us_58cfd4ffe4b00705db50c5e2
# DEBUG:__main__:Exctracting features from https://www.huffingtonpost.com/entry/teen-crocodile-water_us_58cfd4ffe4b00705db50c5e2
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://www.huffingtonpost.com/entry/texas-attorney-generals-office-invents-controversy-over-high-school-muslim-prayers_us_58d0108fe4b0ec9d29de0f3b
# DEBUG:__main__:Exctracting features from https://www.huffingtonpost.com/entry/texas-attorney-generals-office-invents-controversy-over-high-school-muslim-prayers_us_58d0108fe4b0ec9d29de0f3b
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://www.huffingtonpost.com/entry/tomi-lahrens-show-gets-suspended-from-theblaze-after-pro-choice-comments_us_58d03ef9e4b0be71dcf73742
# DEBUG:__main__:Exctracting features from https://www.huffingtonpost.com/entry/tomi-lahrens-show-gets-suspended-from-theblaze-after-pro-choice-comments_us_58d03ef9e4b0be71dcf73742
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Skipping category ARTS & CULTURE
# DEBUG:__main__:Skipping category HEALTHY LIVING
# DEBUG:__main__:Processing url: https://www.huffingtonpost.com/entry/8-perfect-ways-to-incorporate-cats-into-your-home-d%C3%A9cor_us_58865fc6e4b070d8cad48f73
# DEBUG:__main__:Exctracting features from https://www.huffingtonpost.com/entry/8-perfect-ways-to-incorporate-cats-into-your-home-d%C3%A9cor_us_58865fc6e4b070d8cad48f73
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://www.huffingtonpost.com/entry/jason-chaffetz-calls-shut-down-rosie-odonnell_us_58cfe717e4b0be71dcf63732
# DEBUG:__main__:Exctracting features from https://www.huffingtonpost.com/entry/jason-chaffetz-calls-shut-down-rosie-odonnell_us_58cfe717e4b0be71dcf63732
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://www.huffingtonpost.com/entry/can-social-media-loud-and-inclusive-fix-world-politics_us_58cf23e5e4b07112b6472f2d
# DEBUG:__main__:Exctracting features from https://www.huffingtonpost.com/entry/can-social-media-loud-and-inclusive-fix-world-politics_us_58cf23e5e4b07112b6472f2d
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://www.huffingtonpost.com/entry/in-2017-dump-bill-de-blasio_us_58cf2e18e4b07112b6472f39
# DEBUG:__main__:Exctracting features from https://www.huffingtonpost.com/entry/in-2017-dump-bill-de-blasio_us_58cf2e18e4b07112b6472f39
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://www.huffingtonpost.com/entry/director-of-christian-organization-calls-on-christians_us_58cf32c6e4b0e0d348b34519
# DEBUG:__main__:Exctracting features from https://www.huffingtonpost.com/entry/director-of-christian-organization-calls-on-christians_us_58cf32c6e4b0e0d348b34519
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://www.huffingtonpost.com/entry/an-open-letter-to-conservative-politicians-what-does_us_58cf0826e4b07112b6472f19
# DEBUG:__main__:Exctracting features from https://www.huffingtonpost.com/entry/an-open-letter-to-conservative-politicians-what-does_us_58cf0826e4b07112b6472f19
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Skipping category COMEDY
# DEBUG:__main__:Processing url: https://www.huffingtonpost.com/entry/obamacare-vs-trumpcare-a-public-health-dilemma_us_58cf1aade4b0537abd95724d
# DEBUG:__main__:Exctracting features from https://www.huffingtonpost.com/entry/obamacare-vs-trumpcare-a-public-health-dilemma_us_58cf1aade4b0537abd95724d
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://www.huffingtonpost.com/entry/why-the-anti-trump-progressive-mobilization-could-mark_us_58cf9395e4b07112b6472f6e
# DEBUG:__main__:Exctracting features from https://www.huffingtonpost.com/entry/why-the-anti-trump-progressive-mobilization-could-mark_us_58cf9395e4b07112b6472f6e
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Skipping category PARENTS
# DEBUG:__main__:Processing url: https://www.huffingtonpost.com/entry/mccarthyism-20-trumps-first-two-months-in-office_us_58cf9ef2e4b0537abd957290
# DEBUG:__main__:Exctracting features from https://www.huffingtonpost.com/entry/mccarthyism-20-trumps-first-two-months-in-office_us_58cf9ef2e4b0537abd957290
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Skipping category QUEER VOICES
# DEBUG:__main__:Processing url: https://www.huffingtonpost.com/entry/why-bernie-is-the-most-popular-politician-in-america_us_58cef917e4b07112b6472f0e
# DEBUG:__main__:Exctracting features from https://www.huffingtonpost.com/entry/why-bernie-is-the-most-popular-politician-in-america_us_58cef917e4b07112b6472f0e
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Skipping category COMEDY
# DEBUG:__main__:Processing url: https://www.huffingtonpost.com/entry/this-budget-endangers-americans_us_58cec99fe4b0e0d348b344cb
# DEBUG:__main__:Exctracting features from https://www.huffingtonpost.com/entry/this-budget-endangers-americans_us_58cec99fe4b0e0d348b344cb
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Skipping category ENTERTAINMENT
# DEBUG:__main__:Processing url: https://www.huffingtonpost.com/entry/trumps-budget-will-harm-the-planet-and-the-economy_us_58cfcbd1e4b07112b6472f93
# DEBUG:__main__:Exctracting features from https://www.huffingtonpost.com/entry/trumps-budget-will-harm-the-planet-and-the-economy_us_58cfcbd1e4b07112b6472f93
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Skipping category PARENTS
# DEBUG:__main__:Processing url: https://www.huffingtonpost.com/entry/meals-on-wheels-is-working-for-everyone_us_58cfc95be4b0be71dcf60dd5
# DEBUG:__main__:Exctracting features from https://www.huffingtonpost.com/entry/meals-on-wheels-is-working-for-everyone_us_58cfc95be4b0be71dcf60dd5
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://www.huffingtonpost.com/entry/how-trumps-budget-would-hurt-kids-and-us-workers_us_58cfd8d8e4b0537abd9572c8
# DEBUG:__main__:Exctracting features from https://www.huffingtonpost.com/entry/how-trumps-budget-would-hurt-kids-and-us-workers_us_58cfd8d8e4b0537abd9572c8
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://www.huffingtonpost.com/entry/recognizing-teachers-and-preparing-for-peace_us_58cfe2dae4b07112b6472fc8
# DEBUG:__main__:Exctracting features from https://www.huffingtonpost.com/entry/recognizing-teachers-and-preparing-for-peace_us_58cfe2dae4b07112b6472fc8
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://www.huffingtonpost.com/entry/the-need-for-deconstruction-of-the-apocalyptic-state_us_58cd77b5e4b0e0d348b343eb
# DEBUG:__main__:Exctracting features from https://www.huffingtonpost.com/entry/the-need-for-deconstruction-of-the-apocalyptic-state_us_58cd77b5e4b0e0d348b343eb
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://www.huffingtonpost.com/entry/5-issues-to-watch-at-neil-gorsuchs-confirmation-hearing_us_58cfe310e4b0537abd9572e4
# DEBUG:__main__:Exctracting features from https://www.huffingtonpost.com/entry/5-issues-to-watch-at-neil-gorsuchs-confirmation-hearing_us_58cfe310e4b0537abd9572e4
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://www.huffingtonpost.com/entry/conservative-small-business-owners-are-not-victims_us_58cfeb5ce4b07112b6472fdb
# DEBUG:__main__:Exctracting features from https://www.huffingtonpost.com/entry/conservative-small-business-owners-are-not-victims_us_58cfeb5ce4b07112b6472fdb
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Skipping category HEALTHY LIVING
# DEBUG:__main__:Processing url: https://www.huffingtonpost.com/entry/republicans-are-likely-to-use-the-nuclear-option-to_us_58cf546fe4b0537abd957274
# DEBUG:__main__:Exctracting features from https://www.huffingtonpost.com/entry/republicans-are-likely-to-use-the-nuclear-option-to_us_58cf546fe4b0537abd957274
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://www.huffingtonpost.com/entry/europe-needs-to-learn-how-to-work-with-turkey-while_us_58cff91de4b0537abd957315
# DEBUG:__main__:Exctracting features from https://www.huffingtonpost.com/entry/europe-needs-to-learn-how-to-work-with-turkey-while_us_58cff91de4b0537abd957315
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://www.huffingtonpost.com/entry/coretta-scott-purposed-to-be-king_us_58cfefb2e4b0be71dcf647a4
# DEBUG:__main__:Exctracting features from https://www.huffingtonpost.com/entry/coretta-scott-purposed-to-be-king_us_58cfefb2e4b0be71dcf647a4
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://www.huffingtonpost.com/entry/news-roundup-for-march-20-2017_us_58d001cee4b07112b6473016
# DEBUG:__main__:Exctracting features from https://www.huffingtonpost.com/entry/news-roundup-for-march-20-2017_us_58d001cee4b07112b6473016
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://www.huffingtonpost.com/entry/dont-blame-the-batteries-for-every-lithium-ion-explosion_us_58d007bae4b0e0d348b345f6
# DEBUG:__main__:Exctracting features from https://www.huffingtonpost.com/entry/dont-blame-the-batteries-for-every-lithium-ion-explosion_us_58d007bae4b0e0d348b345f6
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://www.huffingtonpost.com/entry/russia-trump-and-the-2016-election-whats-the-best_us_58d000cde4b0e0d348b345ee
# DEBUG:__main__:Exctracting features from https://www.huffingtonpost.com/entry/russia-trump-and-the-2016-election-whats-the-best_us_58d000cde4b0e0d348b345ee
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://www.huffingtonpost.com/entry/neglect-no-more-ending-neglected-tropical-diseases_us_58d011aee4b0537abd95734e
# DEBUG:__main__:Exctracting features from https://www.huffingtonpost.com/entry/neglect-no-more-ending-neglected-tropical-diseases_us_58d011aee4b0537abd95734e
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Skipping category PARENTS
# DEBUG:__main__:Processing url: https://www.huffingtonpost.com/entry/populism-wrong-cost_us_58cfeb03e4b0be71dcf63e6c
# DEBUG:__main__:Exctracting features from https://www.huffingtonpost.com/entry/populism-wrong-cost_us_58cfeb03e4b0be71dcf63e6c
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://www.huffingtonpost.com/entry/being-selfish-and-9-other-things-you-shouldnt-apologize_us_58d01e23e4b0e0d348b3463f
# DEBUG:__main__:Exctracting features from https://www.huffingtonpost.com/entry/being-selfish-and-9-other-things-you-shouldnt-apologize_us_58d01e23e4b0e0d348b3463f
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://www.huffingtonpost.com/entry/trump-is-hurting-the-pentagon-by-giving-it-too-much_us_58d020b6e4b0537abd95736e
# DEBUG:__main__:Exctracting features from https://www.huffingtonpost.com/entry/trump-is-hurting-the-pentagon-by-giving-it-too-much_us_58d020b6e4b0537abd95736e
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Skipping category QUEER VOICES
# DEBUG:__main__:Skipping category TASTE
# DEBUG:__main__:Skipping category STYLE
# DEBUG:__main__:Processing url: https://www.huffingtonpost.com/entry/eat-boldly-indias-street-food-is-worth-it_us_58cd7977e4b0e0d348b343ed
# DEBUG:__main__:Exctracting features from https://www.huffingtonpost.com/entry/eat-boldly-indias-street-food-is-worth-it_us_58cd7977e4b0e0d348b343ed
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://www.huffingtonpost.com/entry/why-coca-leaf-not-coffee-may-always-be-colombias_us_58d0298be4b0537abd957385
# DEBUG:__main__:Exctracting features from https://www.huffingtonpost.com/entry/why-coca-leaf-not-coffee-may-always-be-colombias_us_58d0298be4b0537abd957385
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:==================
#  Processing DATE 2017-03-19
#  URL: https://www.huffingtonpost.com/archive/2017-03-19
# DEBUG:__main__:Processing url: https://www.huffingtonpost.com/entry/kim-jong-un-engine-test_us_58cdd0d9e4b00705db4ff7a1
# DEBUG:__main__:Exctracting features from https://www.huffingtonpost.com/entry/kim-jong-un-engine-test_us_58cdd0d9e4b00705db4ff7a1
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://www.huffingtonpost.com/entry/china-trump-tillerson_us_58ce043ae4b00705db500d5b
# DEBUG:__main__:Exctracting features from https://www.huffingtonpost.com/entry/china-trump-tillerson_us_58ce043ae4b00705db500d5b
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://www.huffingtonpost.com/entry/erdogan-spokesman-germany-behind-coup_us_58cea1aae4b00705db502f30
# DEBUG:__main__:Exctracting features from https://www.huffingtonpost.com/entry/erdogan-spokesman-germany-behind-coup_us_58cea1aae4b00705db502f30
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://www.huffingtonpost.com/entry/syria-fighting-damascus_us_58ced579e4b0be71dcf58b34
# DEBUG:__main__:Exctracting features from https://www.huffingtonpost.com/entry/syria-fighting-damascus_us_58ced579e4b0be71dcf58b34
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://www.huffingtonpost.com/entry/scotland-independence-vote-sturgeon-softens-stance_us_58ce986de4b0ec9d29dcc4da
# DEBUG:__main__:Exctracting features from https://www.huffingtonpost.com/entry/scotland-independence-vote-sturgeon-softens-stance_us_58ce986de4b0ec9d29dcc4da
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://www.huffingtonpost.com/entry/afghan-us-helmand_us_58ce9a83e4b0be71dcf57a42
# DEBUG:__main__:Exctracting features from https://www.huffingtonpost.com/entry/afghan-us-helmand_us_58ce9a83e4b0be71dcf57a42
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://www.huffingtonpost.com/entry/germany-trump-nato-defense-money_us_58ce9691e4b00705db502d37
# DEBUG:__main__:Exctracting features from https://www.huffingtonpost.com/entry/germany-trump-nato-defense-money_us_58ce9691e4b00705db502d37
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://www.huffingtonpost.com/entry/will-hurd-trump-apologize_us_58ce92c3e4b0ec9d29dcc228
# DEBUG:__main__:Exctracting features from https://www.huffingtonpost.com/entry/will-hurd-trump-apologize_us_58ce92c3e4b0ec9d29dcc228
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://www.huffingtonpost.com/entry/ex-police-chief-unlawfully-detained_us_58ceba82e4b00705db503b40
# DEBUG:__main__:Exctracting features from https://www.huffingtonpost.com/entry/ex-police-chief-unlawfully-detained_us_58ceba82e4b00705db503b40
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://www.huffingtonpost.com/entry/why-trump-administration-is-an-oxymoron_us_58cb1996e4b00705db4dd6ae
# DEBUG:__main__:Exctracting features from https://www.huffingtonpost.com/entry/why-trump-administration-is-an-oxymoron_us_58cb1996e4b00705db4dd6ae
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://www.huffingtonpost.com/entry/chesapeake-bay-oysters-trump-budget-cuts_us_58cc4ad5e4b0ec9d29dc23bb
# DEBUG:__main__:Exctracting features from https://www.huffingtonpost.com/entry/chesapeake-bay-oysters-trump-budget-cuts_us_58cc4ad5e4b0ec9d29dc23bb
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://www.huffingtonpost.com/entry/car-bomb-white-house-secret-service_us_58ce16bbe4b0ec9d29dca784
# DEBUG:__main__:Exctracting features from https://www.huffingtonpost.com/entry/car-bomb-white-house-secret-service_us_58ce16bbe4b0ec9d29dca784
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://www.huffingtonpost.com/entry/jimmy-breslin-showed-how-to-torture-people-like-trump-talk-to-the-gravedigger_us_58ceea50e4b0be71dcf599c2
# DEBUG:__main__:Exctracting features from https://www.huffingtonpost.com/entry/jimmy-breslin-showed-how-to-torture-people-like-trump-talk-to-the-gravedigger_us_58ceea50e4b0be71dcf599c2
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://www.huffingtonpost.com/entry/confederate-flag-outside-ncaa-games_us_58ceeb01e4b0be71dcf59ada
# DEBUG:__main__:Exctracting features from https://www.huffingtonpost.com/entry/confederate-flag-outside-ncaa-games_us_58ceeb01e4b0be71dcf59ada
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://www.huffingtonpost.com/entry/nancy-pelosi-trump-wiretap_us_58ceabc5e4b0be71dcf57d59
# DEBUG:__main__:Exctracting features from https://www.huffingtonpost.com/entry/nancy-pelosi-trump-wiretap_us_58ceabc5e4b0be71dcf57d59
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://www.huffingtonpost.com/entry/democrats-supreme-court-neil-gorsuch_us_58ce94cce4b00705db502c82
# DEBUG:__main__:Exctracting features from https://www.huffingtonpost.com/entry/democrats-supreme-court-neil-gorsuch_us_58ce94cce4b00705db502c82
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Skipping category ENTERTAINMENT
# DEBUG:__main__:Processing url: https://www.huffingtonpost.com/entry/trump-insurance-mulvaney_us_58cea736e4b00705db502fef
# DEBUG:__main__:Exctracting features from https://www.huffingtonpost.com/entry/trump-insurance-mulvaney_us_58cea736e4b00705db502fef
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://www.huffingtonpost.com/entry/jimmy-breslin-dead_us_58ce9477e4b0be71dcf577b1
# DEBUG:__main__:Exctracting features from https://www.huffingtonpost.com/entry/jimmy-breslin-dead_us_58ce9477e4b0be71dcf577b1
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://www.huffingtonpost.com/entry/trump-wiretap-evidence_us_58ce8cdfe4b0be71dcf574fb
# DEBUG:__main__:Exctracting features from https://www.huffingtonpost.com/entry/trump-wiretap-evidence_us_58ce8cdfe4b0be71dcf574fb
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Skipping category QUEER VOICES
# DEBUG:__main__:Processing url: https://www.huffingtonpost.com/entry/tom-price-obamacare-repeal-democrats_us_58ce9e61e4b0ec9d29dcc5a0
# DEBUG:__main__:Exctracting features from https://www.huffingtonpost.com/entry/tom-price-obamacare-repeal-democrats_us_58ce9e61e4b0ec9d29dcc5a0
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Skipping category ENTERTAINMENT
# DEBUG:__main__:Processing url: https://www.huffingtonpost.com/entry/uber-president-resigns_us_58cf05bce4b00705db50534e
# DEBUG:__main__:Exctracting features from https://www.huffingtonpost.com/entry/uber-president-resigns_us_58cf05bce4b00705db50534e
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://www.huffingtonpost.com/entry/previously-undiscovered-manuscript-reveals-things-jesus_us_58cdcdfee4b0537abd95718e
# DEBUG:__main__:Exctracting features from https://www.huffingtonpost.com/entry/previously-undiscovered-manuscript-reveals-things-jesus_us_58cdcdfee4b0537abd95718e
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Skipping category PARENTS
# DEBUG:__main__:Processing url: https://www.huffingtonpost.com/entry/not-my-feminism_us_58ce0f6de4b07112b6472e91
# DEBUG:__main__:Exctracting features from https://www.huffingtonpost.com/entry/not-my-feminism_us_58ce0f6de4b07112b6472e91
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Skipping category QUEER VOICES
# DEBUG:__main__:Skipping category ENTERTAINMENT
# DEBUG:__main__:Processing url: https://www.huffingtonpost.com/entry/how-trumps-skinny-budget-starves-environmental-protection_us_58ce586be4b07112b6472ea7
# DEBUG:__main__:Exctracting features from https://www.huffingtonpost.com/entry/how-trumps-skinny-budget-starves-environmental-protection_us_58ce586be4b07112b6472ea7
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Skipping category ARTS & CULTURE
# DEBUG:__main__:Skipping category TASTE
# DEBUG:__main__:Processing url: https://www.huffingtonpost.com/entry/a-third-way-for-universities_us_58ce8a71e4b07112b6472ec4
# DEBUG:__main__:Exctracting features from https://www.huffingtonpost.com/entry/a-third-way-for-universities_us_58ce8a71e4b07112b6472ec4
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Skipping category STYLE
# DEBUG:__main__:Processing url: https://www.huffingtonpost.com/entry/if-the-democrats-cave-on-gorsuch-theyll-be-terribly_us_58ce9c60e4b0e0d348b3449b
# DEBUG:__main__:Exctracting features from https://www.huffingtonpost.com/entry/if-the-democrats-cave-on-gorsuch-theyll-be-terribly_us_58ce9c60e4b0e0d348b3449b
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Skipping category HEALTHY LIVING
# DEBUG:__main__:Processing url: https://www.huffingtonpost.com/entry/trumps-skinny-budget-would-put-educators-learning_us_58ceb4a4e4b0537abd9571fb
# DEBUG:__main__:Exctracting features from https://www.huffingtonpost.com/entry/trumps-skinny-budget-would-put-educators-learning_us_58ceb4a4e4b0537abd9571fb
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://www.huffingtonpost.com/entry/the-gorsuch-nomination-and-the-rule-of-law_us_58cebb3ce4b0e0d348b344bc
# DEBUG:__main__:Exctracting features from https://www.huffingtonpost.com/entry/the-gorsuch-nomination-and-the-rule-of-law_us_58cebb3ce4b0e0d348b344bc
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://www.huffingtonpost.com/entry/what-would-a-post-planned-parenthood-world-look-like_us_58cb624ae4b0537abd956f82
# DEBUG:__main__:Exctracting features from https://www.huffingtonpost.com/entry/what-would-a-post-planned-parenthood-world-look-like_us_58cb624ae4b0537abd956f82
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://www.huffingtonpost.com/entry/mr-attorney-general-im-a-product-of-just-say-no_us_58ced1dde4b0e0d348b344d1
# DEBUG:__main__:Exctracting features from https://www.huffingtonpost.com/entry/mr-attorney-general-im-a-product-of-just-say-no_us_58ced1dde4b0e0d348b344d1
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://www.huffingtonpost.com/entry/a-principled-reason-to-oppose-the-confirmation-of-neil_us_58cef74ee4b0e0d348b344f8
# DEBUG:__main__:Exctracting features from https://www.huffingtonpost.com/entry/a-principled-reason-to-oppose-the-confirmation-of-neil_us_58cef74ee4b0e0d348b344f8
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://www.huffingtonpost.com/entry/remembering-jimmy-breslin-and-the-newspaper-world_us_58cf02bee4b0e0d348b34501
# DEBUG:__main__:Exctracting features from https://www.huffingtonpost.com/entry/remembering-jimmy-breslin-and-the-newspaper-world_us_58cf02bee4b0e0d348b34501
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://www.huffingtonpost.com/entry/trump-work-mar-a-lago_us_58cde456e4b0be71dcf54620
# DEBUG:__main__:Exctracting features from https://www.huffingtonpost.com/entry/trump-work-mar-a-lago_us_58cde456e4b0be71dcf54620
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://www.huffingtonpost.com/entry/in-sickness-and-for-the-wealthy-in-health_us_58ce8117e4b07112b6472ebd
# DEBUG:__main__:Exctracting features from https://www.huffingtonpost.com/entry/in-sickness-and-for-the-wealthy-in-health_us_58ce8117e4b07112b6472ebd
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Skipping category HEALTHY LIVING
# DEBUG:__main__:Processing url: https://www.huffingtonpost.com/entry/mouth-swab-marijuana_us_58ce0c7ce4b0be71dcf55bc6
# DEBUG:__main__:Exctracting features from https://www.huffingtonpost.com/entry/mouth-swab-marijuana_us_58ce0c7ce4b0be71dcf55bc6
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://www.huffingtonpost.com/entry/trump-jr-style-twitter_us_58cdbb2de4b0ec9d29dc87f6
# DEBUG:__main__:Exctracting features from https://www.huffingtonpost.com/entry/trump-jr-style-twitter_us_58cdbb2de4b0ec9d29dc87f6
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Skipping category PARENTS
# DEBUG:__main__:Processing url: https://www.huffingtonpost.com/entry/three-reasons-you-need-to-say-no-more-often_us_58ce4475e4b0e0d348b34466
# DEBUG:__main__:Exctracting features from https://www.huffingtonpost.com/entry/three-reasons-you-need-to-say-no-more-often_us_58ce4475e4b0e0d348b34466
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://www.huffingtonpost.com/entry/our-country-must-be-saved-from-gerrymandering_us_58cec0d2e4b07112b6472eed
# DEBUG:__main__:Exctracting features from https://www.huffingtonpost.com/entry/our-country-must-be-saved-from-gerrymandering_us_58cec0d2e4b07112b6472eed
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Skipping category HEALTHY LIVING
# DEBUG:__main__:Processing url: https://www.huffingtonpost.com/entry/14-years-after-invasion-iraq-wars-lessons-still-unlearned_us_58ceb599e4b07112b6472ede
# DEBUG:__main__:Exctracting features from https://www.huffingtonpost.com/entry/14-years-after-invasion-iraq-wars-lessons-still-unlearned_us_58ceb599e4b07112b6472ede
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://www.huffingtonpost.com/entry/spreading-the-gospel-asian-leaders-wary-of-saudi-religious_us_58ce7059e4b07112b6472eb4
# DEBUG:__main__:Exctracting features from https://www.huffingtonpost.com/entry/spreading-the-gospel-asian-leaders-wary-of-saudi-religious_us_58ce7059e4b07112b6472eb4
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Skipping category ENTERTAINMENT
# DEBUG:__main__:Skipping category ENTERTAINMENT
# DEBUG:__main__:Skipping category ARTS & CULTURE
# DEBUG:__main__:Processing url: https://www.huffingtonpost.com/entry/russian-zoo-porn-raccoon_us_58cccd8ee4b00705db4fd08d
# DEBUG:__main__:Exctracting features from https://www.huffingtonpost.com/entry/russian-zoo-porn-raccoon_us_58cccd8ee4b00705db4fd08d
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://www.huffingtonpost.com/entry/tomi-lahren-pro-choice_us_58cde0e3e4b00705db4ffb27
# DEBUG:__main__:Exctracting features from https://www.huffingtonpost.com/entry/tomi-lahren-pro-choice_us_58cde0e3e4b00705db4ffb27
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://www.huffingtonpost.com/entry/the-cias-60-year-history-of-fake-news-how-the-deep_us_58ce115fe4b07112b6472e93
# DEBUG:__main__:Exctracting features from https://www.huffingtonpost.com/entry/the-cias-60-year-history-of-fake-news-how-the-deep_us_58ce115fe4b07112b6472e93
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://www.huffingtonpost.com/entry/jimmy-breslin-dead_us_58ce9e9ee4b0ec9d29dcc5a5
# DEBUG:__main__:Exctracting features from https://www.huffingtonpost.com/entry/jimmy-breslin-dead_us_58ce9e9ee4b0ec9d29dcc5a5
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://www.huffingtonpost.com/entry/panther-bots-robotics-team-racism_us_58ce3417e4b0ec9d29dcacae
# DEBUG:__main__:Exctracting features from https://www.huffingtonpost.com/entry/panther-bots-robotics-team-racism_us_58ce3417e4b0ec9d29dcacae
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Skipping category HEALTHY LIVING
# DEBUG:__main__:Skipping category ENTERTAINMENT
# DEBUG:__main__:Processing url: https://www.huffingtonpost.com/entry/the-deadly-war-on-drugs-waged-by-your-local-swat-team_us_58ce980de4b0e0d348b34497
# DEBUG:__main__:Exctracting features from https://www.huffingtonpost.com/entry/the-deadly-war-on-drugs-waged-by-your-local-swat-team_us_58ce980de4b0e0d348b34497
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://www.huffingtonpost.com/entry/boulder-sunshine-fire_us_58ceee3fe4b0ec9d29dce725
# DEBUG:__main__:Exctracting features from https://www.huffingtonpost.com/entry/boulder-sunshine-fire_us_58ceee3fe4b0ec9d29dce725
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://www.huffingtonpost.com/entry/brian-stelter-fox-news-presidency_us_58ccc25de4b0ec9d29dc661e
# DEBUG:__main__:Exctracting features from https://www.huffingtonpost.com/entry/brian-stelter-fox-news-presidency_us_58ccc25de4b0ec9d29dc661e
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://www.huffingtonpost.com/entry/obamacare-repeal-premiums_us_58cc4cc0e4b0be71dcf4dba4
# DEBUG:__main__:Exctracting features from https://www.huffingtonpost.com/entry/obamacare-repeal-premiums_us_58cc4cc0e4b0be71dcf4dba4
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Skipping category SPORTS
# DEBUG:__main__:==================
#  Processing DATE 2017-03-18
#  URL: https://www.huffingtonpost.com/archive/2017-03-18
# DEBUG:__main__:Processing url: https://www.huffingtonpost.com/entry/pentagon-civilian-nominees-missing_us_58cb0b09e4b00705db4dca3f
# DEBUG:__main__:Exctracting features from https://www.huffingtonpost.com/entry/pentagon-civilian-nominees-missing_us_58cb0b09e4b00705db4dca3f
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Skipping category COMEDY
# DEBUG:__main__:Processing url: https://www.huffingtonpost.com/entry/paris-airport-orly-soldier_us_58ccf105e4b0be71dcf51f0b
# DEBUG:__main__:Exctracting features from https://www.huffingtonpost.com/entry/paris-airport-orly-soldier_us_58ccf105e4b0be71dcf51f0b
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://www.huffingtonpost.com/entry/rex-tillerson-traveling-press_us_58cd41c7e4b0be71dcf52cee
# DEBUG:__main__:Exctracting features from https://www.huffingtonpost.com/entry/rex-tillerson-traveling-press_us_58cd41c7e4b0be71dcf52cee
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://www.huffingtonpost.com/entry/crimea-putin-aksyonov_us_58cd93cce4b0ec9d29dc8638
# DEBUG:__main__:Exctracting features from https://www.huffingtonpost.com/entry/crimea-putin-aksyonov_us_58cd93cce4b0ec9d29dc8638
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://www.huffingtonpost.com/entry/trump-us-mexico-border-wall-proposals_us_58cd9881e4b0ec9d29dc86a2
# DEBUG:__main__:Exctracting features from https://www.huffingtonpost.com/entry/trump-us-mexico-border-wall-proposals_us_58cd9881e4b0ec9d29dc86a2
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://www.huffingtonpost.com/entry/trump-germany-nato-funding_us_58cd3ec9e4b0be71dcf52c51
# DEBUG:__main__:Exctracting features from https://www.huffingtonpost.com/entry/trump-germany-nato-funding_us_58cd3ec9e4b0be71dcf52c51
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Skipping category COMEDY
# DEBUG:__main__:Processing url: https://www.huffingtonpost.com/entry/santorum-trump-wiretap_us_58ccb356e4b00705db4fcb70
# DEBUG:__main__:Exctracting features from https://www.huffingtonpost.com/entry/santorum-trump-wiretap_us_58ccb356e4b00705db4fcb70
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Skipping category WEDDINGS
# DEBUG:__main__:Processing url: https://www.huffingtonpost.com/entry/neil-gorsuch-students-with-disabilities_us_58c8bcfde4b09e52f5547b86
# DEBUG:__main__:Exctracting features from https://www.huffingtonpost.com/entry/neil-gorsuch-students-with-disabilities_us_58c8bcfde4b09e52f5547b86
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://www.huffingtonpost.com/entry/tom-perez-dnc-transition-team-progressive-critics_us_58cd2cfce4b0be71dcf5295f
# DEBUG:__main__:Exctracting features from https://www.huffingtonpost.com/entry/tom-perez-dnc-transition-team-progressive-critics_us_58cd2cfce4b0be71dcf5295f
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://www.huffingtonpost.com/entry/trumpcare-mental-health-paul-ryan_us_58cb9812e4b0be71dcf36721
# DEBUG:__main__:Exctracting features from https://www.huffingtonpost.com/entry/trumpcare-mental-health-paul-ryan_us_58cb9812e4b0be71dcf36721
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://www.huffingtonpost.com/entry/g20-free-trade-pledge-dropped_us_58cd770de4b0be71dcf53953
# DEBUG:__main__:Exctracting features from https://www.huffingtonpost.com/entry/g20-free-trade-pledge-dropped_us_58cd770de4b0be71dcf53953
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Skipping category ENTERTAINMENT
# DEBUG:__main__:Processing url: https://www.huffingtonpost.com/entry/that-deplorable-free-lunch-argument_us_58cc7d31e4b0e0d348b3436b
# DEBUG:__main__:Exctracting features from https://www.huffingtonpost.com/entry/that-deplorable-free-lunch-argument_us_58cc7d31e4b0e0d348b3436b
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://www.huffingtonpost.com/entry/turkey-netherlands-spat-europe_us_58cc05a1e4b0be71dcf45d71
# DEBUG:__main__:Exctracting features from https://www.huffingtonpost.com/entry/turkey-netherlands-spat-europe_us_58cc05a1e4b0be71dcf45d71
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://www.huffingtonpost.com/entry/weekend-roundup-161_us_58cbed8ae4b0be71dcf421a5
# DEBUG:__main__:Exctracting features from https://www.huffingtonpost.com/entry/weekend-roundup-161_us_58cbed8ae4b0be71dcf421a5
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://www.huffingtonpost.com/entry/ameri-can-or-ameri-wont_us_58cc87c5e4b0e0d348b3436e
# DEBUG:__main__:Exctracting features from https://www.huffingtonpost.com/entry/ameri-can-or-ameri-wont_us_58cc87c5e4b0e0d348b3436e
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://www.huffingtonpost.com/entry/respect-seniors-increase-funding-for-meals-on-wheels_us_58ccb2d2e4b0e0d348b3437a
# DEBUG:__main__:Exctracting features from https://www.huffingtonpost.com/entry/respect-seniors-increase-funding-for-meals-on-wheels_us_58ccb2d2e4b0e0d348b3437a
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://www.huffingtonpost.com/entry/grading-nations-on-human-rights-and-religious-freedom_us_58cd2b9de4b0e0d348b3439d
# DEBUG:__main__:Exctracting features from https://www.huffingtonpost.com/entry/grading-nations-on-human-rights-and-religious-freedom_us_58cd2b9de4b0e0d348b3439d
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://www.huffingtonpost.com/entry/neil-gorsuch-ghostbuster_us_58cd27d1e4b0e0d348b3439c
# DEBUG:__main__:Exctracting features from https://www.huffingtonpost.com/entry/neil-gorsuch-ghostbuster_us_58cd27d1e4b0e0d348b3439c
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://www.huffingtonpost.com/entry/sky-high-drug-prices-for-rare-diseases-show-why-orphan_us_58cd353de4b07112b6472ded
# DEBUG:__main__:Exctracting features from https://www.huffingtonpost.com/entry/sky-high-drug-prices-for-rare-diseases-show-why-orphan_us_58cd353de4b07112b6472ded
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://www.huffingtonpost.com/entry/ryancare-sparks-debate-between-democrats-and-republicans_us_58cd38bee4b0e0d348b343a7
# DEBUG:__main__:Exctracting features from https://www.huffingtonpost.com/entry/ryancare-sparks-debate-between-democrats-and-republicans_us_58cd38bee4b0e0d348b343a7
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://www.huffingtonpost.com/entry/no-great-deal-on-the-horizon_us_58cd3a3be4b07112b6472df1
# DEBUG:__main__:Exctracting features from https://www.huffingtonpost.com/entry/no-great-deal-on-the-horizon_us_58cd3a3be4b07112b6472df1
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://www.huffingtonpost.com/entry/the-deeply-disturbing-trump-merkel-press-conference_us_58cd4a4ce4b0e0d348b343c0
# DEBUG:__main__:Exctracting features from https://www.huffingtonpost.com/entry/the-deeply-disturbing-trump-merkel-press-conference_us_58cd4a4ce4b0e0d348b343c0
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Skipping category SPORTS
# DEBUG:__main__:Processing url: https://www.huffingtonpost.com/entry/budgeting-social-darwinism_us_58cd6a93e4b0e0d348b343d7
# DEBUG:__main__:Exctracting features from https://www.huffingtonpost.com/entry/budgeting-social-darwinism_us_58cd6a93e4b0e0d348b343d7
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://www.huffingtonpost.com/entry/end-nato-expansion-with-montenegro-more-movie-set_us_58cd789fe4b0e0d348b343ec
# DEBUG:__main__:Exctracting features from https://www.huffingtonpost.com/entry/end-nato-expansion-with-montenegro-more-movie-set_us_58cd789fe4b0e0d348b343ec
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Skipping category HEALTHY LIVING
# DEBUG:__main__:Processing url: https://www.huffingtonpost.com/entry/why-meals-on-wheels-should-actually-thank-trump-and-his-budget-director_us_58cd95dce4b0ec9d29dc8679
# DEBUG:__main__:Exctracting features from https://www.huffingtonpost.com/entry/why-meals-on-wheels-should-actually-thank-trump-and-his-budget-director_us_58cd95dce4b0ec9d29dc8679
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Skipping category QUEER VOICES
# DEBUG:__main__:Processing url: https://www.huffingtonpost.com/entry/black-history-everyday-247365-chuck-berry_us_58cdb665e4b0e0d348b3441b
# DEBUG:__main__:Exctracting features from https://www.huffingtonpost.com/entry/black-history-everyday-247365-chuck-berry_us_58cdb665e4b0e0d348b3441b
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Skipping category WEDDINGS
# DEBUG:__main__:Skipping category ENTERTAINMENT
# DEBUG:__main__:Skipping category ENTERTAINMENT
# DEBUG:__main__:Processing url: https://www.huffingtonpost.com/entry/arrest-seizure-gif-reporter-kurt-eichenwald_us_58cc850ae4b00705db4fc429
# DEBUG:__main__:Exctracting features from https://www.huffingtonpost.com/entry/arrest-seizure-gif-reporter-kurt-eichenwald_us_58cc850ae4b00705db4fc429
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://www.huffingtonpost.com/entry/report-russian-elite-invested-nearly-100-million-in-trump-buildings-records-show_us_58cc8d96e4b0be71dcf50fc6
# ...
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://www.huffingtonpost.com/entry/twitter-mistakes-brands_us_58caafa2e4b0ec9d29d95dc5
# DEBUG:__main__:Exctracting features from https://www.huffingtonpost.com/entry/twitter-mistakes-brands_us_58caafa2e4b0ec9d29d95dc5
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://www.huffingtonpost.com/entry/youngest-conductor-75-piece-orchestra_us_58ca9adee4b0be71dcf1eb58
# DEBUG:__main__:Exctracting features from https://www.huffingtonpost.com/entry/youngest-conductor-75-piece-orchestra_us_58ca9adee4b0be71dcf1eb58
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Skipping category TASTE
# DEBUG:__main__:Processing url: https://www.huffingtonpost.com/entry/tom-price-cancer-survivor-medicaid_us_58ca56cde4b0ec9d29d8c63b
# DEBUG:__main__:Exctracting features from https://www.huffingtonpost.com/entry/tom-price-cancer-survivor-medicaid_us_58ca56cde4b0ec9d29d8c63b
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Skipping category HEALTHY LIVING
# DEBUG:__main__:Skipping category ARTS & CULTURE
# DEBUG:__main__:Processing url: https://www.huffingtonpost.com/entry/trump-meals-on-wheels_us_58caeda5e4b0ec9d29da217c
# DEBUG:__main__:Exctracting features from https://www.huffingtonpost.com/entry/trump-meals-on-wheels_us_58caeda5e4b0ec9d29da217c
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Skipping category ARTS & CULTURE
# DEBUG:__main__:Processing url: https://www.huffingtonpost.com/entry/latino-rep-calls-out-republicans-for-normalizing-steve-kings-racist-comments_us_58caed35e4b00705db4d898a
# DEBUG:__main__:Exctracting features from https://www.huffingtonpost.com/entry/latino-rep-calls-out-republicans-for-normalizing-steve-kings-racist-comments_us_58caed35e4b00705db4d898a
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://www.huffingtonpost.com/entry/white-house-budget-epa_us_58ca746be4b0be71dcf1ad3d
# DEBUG:__main__:Exctracting features from https://www.huffingtonpost.com/entry/white-house-budget-epa_us_58ca746be4b0be71dcf1ad3d
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Skipping category ENTERTAINMENT
# DEBUG:__main__:Processing url: https://www.huffingtonpost.com/entry/polls-le-pen-france-presidential-election_us_58c9ae5de4b0ec9d29d8733a
# DEBUG:__main__:Exctracting features from https://www.huffingtonpost.com/entry/polls-le-pen-france-presidential-election_us_58c9ae5de4b0ec9d29d8733a
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Skipping category ENTERTAINMENT
# DEBUG:__main__:Skipping category SPORTS
# DEBUG:__main__:Processing url: https://www.huffingtonpost.com/entry/federal-ruling-travel-ban-text_us_58c9d602e4b0ec9d29d89cfb
# DEBUG:__main__:Exctracting features from https://www.huffingtonpost.com/entry/federal-ruling-travel-ban-text_us_58c9d602e4b0ec9d29d89cfb
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://www.huffingtonpost.com/entry/de-blasio-corruption-charges_us_58caac11e4b0ec9d29d9598d
# DEBUG:__main__:Exctracting features from https://www.huffingtonpost.com/entry/de-blasio-corruption-charges_us_58caac11e4b0ec9d29d9598d
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Skipping category ARTS & CULTURE
# DEBUG:__main__:Processing url: https://www.huffingtonpost.com/entry/jim-inhofe-epa-brainwashing-children-us_us_58cad008e4b0ec9d29d9d1e3
# DEBUG:__main__:Exctracting features from https://www.huffingtonpost.com/entry/jim-inhofe-epa-brainwashing-children-us_us_58cad008e4b0ec9d29d9d1e3
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Skipping category ARTS & CULTURE
# DEBUG:__main__:Processing url: https://www.huffingtonpost.com/entry/trump-budget-food-clean-water-funding_us_58ca1297e4b0ec9d29d8a9a1
# DEBUG:__main__:Exctracting features from https://www.huffingtonpost.com/entry/trump-budget-food-clean-water-funding_us_58ca1297e4b0ec9d29d8a9a1
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Skipping category QUEER VOICES
# DEBUG:__main__:Processing url: https://www.huffingtonpost.com/entry/ivanka-trump-child-care-budget_us_58cafe45e4b0ec9d29da47eb
# DEBUG:__main__:Exctracting features from https://www.huffingtonpost.com/entry/ivanka-trump-child-care-budget_us_58cafe45e4b0ec9d29da47eb
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Skipping category HEALTHY LIVING
# DEBUG:__main__:Skipping category ENTERTAINMENT
# DEBUG:__main__:Skipping category TASTE
# DEBUG:__main__:Processing url: https://www.huffingtonpost.com/entry/white-house-budget-sesame-street-pbs_us_58ca8cade4b0be71dcf1d3eb
# DEBUG:__main__:Exctracting features from https://www.huffingtonpost.com/entry/white-house-budget-sesame-street-pbs_us_58ca8cade4b0be71dcf1d3eb
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://www.huffingtonpost.com/entry/danny-glover-protest-in-the-age-of-trump_us_58cac574e4b00705db4d150a
# DEBUG:__main__:Exctracting features from https://www.huffingtonpost.com/entry/danny-glover-protest-in-the-age-of-trump_us_58cac574e4b00705db4d150a
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Skipping category ENTERTAINMENT
# DEBUG:__main__:Skipping category COMEDY
# DEBUG:__main__:Skipping category STYLE
# DEBUG:__main__:Processing url: https://www.huffingtonpost.com/entry/conservatives-health-care-bill-changes_us_58c9fbe7e4b0be71dcf16394
# DEBUG:__main__:Exctracting features from https://www.huffingtonpost.com/entry/conservatives-health-care-bill-changes_us_58c9fbe7e4b0be71dcf16394
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://www.huffingtonpost.com/entry/huffpost-hill-trump-to-eminent-domain-grandmas-dinner_us_58cb0b97e4b00705db4dcadf
# DEBUG:__main__:Exctracting features from https://www.huffingtonpost.com/entry/huffpost-hill-trump-to-eminent-domain-grandmas-dinner_us_58cb0b97e4b00705db4dcadf
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://www.huffingtonpost.com/entry/progressives-tom-perez-dnc-transition-committee_us_58cab459e4b0ec9d29d9695f
# DEBUG:__main__:Exctracting features from https://www.huffingtonpost.com/entry/progressives-tom-perez-dnc-transition-committee_us_58cab459e4b0ec9d29d9695f
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Skipping category ENTERTAINMENT
# DEBUG:__main__:Skipping category ENTERTAINMENT
# DEBUG:__main__:Processing url: https://www.huffingtonpost.com/entry/couple-urinating-quran-santa-fe-library_us_58c9e649e4b00705db4c0b0e
# DEBUG:__main__:Exctracting features from https://www.huffingtonpost.com/entry/couple-urinating-quran-santa-fe-library_us_58c9e649e4b00705db4c0b0e
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://www.huffingtonpost.com/entry/new-york-surfer-asks-news-crew-for-ride_us_58ca0709e4b00705db4c131c
# DEBUG:__main__:Exctracting features from https://www.huffingtonpost.com/entry/new-york-surfer-asks-news-crew-for-ride_us_58ca0709e4b00705db4c131c
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://www.huffingtonpost.com/entry/michael-flynn-russia-payments_us_58cac910e4b0ec9d29d9ba8c
# DEBUG:__main__:Exctracting features from https://www.huffingtonpost.com/entry/michael-flynn-russia-payments_us_58cac910e4b0ec9d29d9ba8c
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Skipping category ENTERTAINMENT
# DEBUG:__main__:Processing url: https://www.huffingtonpost.com/entry/trump-budget-air-traffic-control_us_58ca2f55e4b00705db4c1de2
# DEBUG:__main__:Exctracting features from https://www.huffingtonpost.com/entry/trump-budget-air-traffic-control_us_58ca2f55e4b00705db4c1de2
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://www.huffingtonpost.com/entry/bow-wow-and-why-fighting-trump-with-sexism-aint-the-look_us_58ca9e29e4b0ec9d29d937b8
# DEBUG:__main__:Exctracting features from https://www.huffingtonpost.com/entry/bow-wow-and-why-fighting-trump-with-sexism-aint-the-look_us_58ca9e29e4b0ec9d29d937b8
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://www.huffingtonpost.com/entry/train-hits-commuters-with-an-avalanche-of-snow_us_58ca9989e4b00705db4c9605
# DEBUG:__main__:Exctracting features from https://www.huffingtonpost.com/entry/train-hits-commuters-with-an-avalanche-of-snow_us_58ca9989e4b00705db4c9605
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Skipping category COMEDY
# DEBUG:__main__:Processing url: https://www.huffingtonpost.com/entry/amazon-alexa-talking-skull_us_58c9b77de4b00705db4bf02a
# DEBUG:__main__:Exctracting features from https://www.huffingtonpost.com/entry/amazon-alexa-talking-skull_us_58c9b77de4b00705db4bf02a
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://www.huffingtonpost.com/entry/doctors-unite-to-say-climate-change-is-making-us-sick_us_58ca9234e4b0e0d348b340b2
# DEBUG:__main__:Exctracting features from https://www.huffingtonpost.com/entry/doctors-unite-to-say-climate-change-is-making-us-sick_us_58ca9234e4b0e0d348b340b2
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://www.huffingtonpost.com/entry/these-will-be-the-best-places-to-live-in-america-in_us_58ca9567e4b07112b6472b22
# DEBUG:__main__:Exctracting features from https://www.huffingtonpost.com/entry/these-will-be-the-best-places-to-live-in-america-in_us_58ca9567e4b07112b6472b22
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:==================
#  Processing DATE 2017-03-15
#  URL: https://www.huffingtonpost.com/archive/2017-03-15
# DEBUG:__main__:Processing url: https://www.huffingtonpost.com/entry/american-airlines-free-meals-economy-some-flights_us_58c8a5b7e4b09e52f554738f
# DEBUG:__main__:Exctracting features from https://www.huffingtonpost.com/entry/american-airlines-free-meals-economy-some-flights_us_58c8a5b7e4b09e52f554738f
# DEBUG:__main__:Saved to DB
# DEBUG:__main__:Processing url: https://www.huffingtonpost.com/entry/exploding-headphones-on-flight-burn-womans-face_us_58c90d42e4b01c029d778241
# DEBUG:__main__:Exctracting features from https://www.huffingtonpost.com/entry/exploding-headphones-on-flight-burn-womans-face_us_58c90d42e4b01c029d778241
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-e1db2753f677> in <module>()
#      34                         url = urljoin(base_url, a['href'])
#      35                         log.debug(f"Processing url: {url}")
# ---> 36                         article_date = scrape(url, db, collection)
#      37                     except Exception as e:
#      38                         log.debug(e)
#
# <ipython-input-2-3d9531747960> in scrape(url, db, collection)
#      72         'title'   :article.title,
#      73         'text'    :article.text,
# ---> 74         'authors' :article.authors
#      75     })
#      76
#
# <ipython-input-2-3d9531747960> in saveToDB(db, collection, url, html, meta)
#      33         }
#      34         ,
# ---> 35         upsert=True
#      36     )
#      37     log.debug(f'Saved to DB')
#
# ~/anaconda3/lib/python3.6/site-packages/pymongo/collection.py in update_one(self, filter, update, upsert, bypass_document_validation, collation, array_filters, session)
#     993                 bypass_doc_val=bypass_document_validation,
#     994                 collation=collation, array_filters=array_filters,
# --> 995                 session=session),
#     996             write_concern.acknowledged)
#     997
#
# ~/anaconda3/lib/python3.6/site-packages/pymongo/collection.py in _update_retryable(self, criteria, document, upsert, check_keys, multi, manipulate, write_concern, op_id, ordered, bypass_doc_val, collation, array_filters, session)
#     849         return self.__database.client._retryable_write(
#     850             (write_concern or self.write_concern).acknowledged and not multi,
# --> 851             _update, session)
#     852
#     853     def replace_one(self, filter, replacement, upsert=False,
#
# ~/anaconda3/lib/python3.6/site-packages/pymongo/mongo_client.py in _retryable_write(self, retryable, func, session)
#    1241         """Internal retryable write helper."""
#    1242         with self._tmp_session(session) as s:
# -> 1243             return self._retry_with_session(retryable, func, s, None)
#    1244
#    1245     def __reset_server(self, address):
#
# ~/anaconda3/lib/python3.6/site-packages/pymongo/mongo_client.py in _retry_with_session(self, retryable, func, session, bulk)
#    1194                         # Reset the transaction id and retry the operation.
#    1195                         session._retry_transaction_id()
# -> 1196                     return func(session, sock_info, retryable)
#    1197             except ServerSelectionTimeoutError:
#    1198                 if is_retrying():
#
# ~/anaconda3/lib/python3.6/site-packages/pymongo/collection.py in _update(session, sock_info, retryable_write)
#     845                 bypass_doc_val=bypass_doc_val, collation=collation,
#     846                 array_filters=array_filters, session=session,
# --> 847                 retryable_write=retryable_write)
#     848
#     849         return self.__database.client._retryable_write(
#
# ~/anaconda3/lib/python3.6/site-packages/pymongo/collection.py in _update(self, sock_info, criteria, document, upsert, check_keys, multi, manipulate, write_concern, op_id, ordered, bypass_doc_val, collation, array_filters, session, retryable_write)
#     815             session=session,
#     816             client=self.__database.client,
# --> 817             retryable_write=retryable_write).copy()
#     818         _check_write_command_response(result)
#     819         # Add the updatedExisting field for compatibility.
#
# ~/anaconda3/lib/python3.6/site-packages/pymongo/pool.py in command(self, dbname, spec, slave_ok, read_preference, codec_options, check, allowable_errors, check_keys, read_concern, write_concern, parse_write_concern_error, collation, session, client, retryable_write, publish_events)
#     582         # Catch socket.error, KeyboardInterrupt, etc. and close ourselves.
#     583         except BaseException as error:
# --> 584             self._raise_connection_failure(error)
#     585
#     586     def send_message(self, message, max_doc_size):
#
# ~/anaconda3/lib/python3.6/site-packages/pymongo/pool.py in _raise_connection_failure(self, error)
#     743             _raise_connection_failure(self.address, error)
#     744         else:
# --> 745             raise error
#     746
#     747     def __eq__(self, other):
#
# ~/anaconda3/lib/python3.6/site-packages/pymongo/pool.py in command(self, dbname, spec, slave_ok, read_preference, codec_options, check, allowable_errors, check_keys, read_concern, write_concern, parse_write_concern_error, collation, session, client, retryable_write, publish_events)
#     577                            compression_ctx=self.compression_context,
#     578                            use_op_msg=self.op_msg_enabled,
# --> 579                            unacknowledged=unacknowledged)
#     580         except OperationFailure:
#     581             raise
#
# ~/anaconda3/lib/python3.6/site-packages/pymongo/network.py in command(sock, dbname, spec, slave_ok, is_mongos, read_preference, codec_options, session, client, check, allowable_errors, address, check_keys, listeners, max_bson_size, read_concern, parse_write_concern_error, collation, compression_ctx, use_op_msg, unacknowledged)
#     139             response_doc = {"ok": 1}
#     140         else:
# --> 141             reply = receive_message(sock, request_id)
#     142             unpacked_docs = reply.unpack_response(codec_options=codec_options)
#     143
#
# ~/anaconda3/lib/python3.6/site-packages/pymongo/network.py in receive_message(sock, request_id, max_message_size)
#     171     # Ignore the response's request id.
#     172     length, _, response_to, op_code = _UNPACK_HEADER(
# --> 173         _receive_data_on_socket(sock, 16))
#     174     # No request_id for exhaust cursor "getMore".
#     175     if request_id is not None:
#
# ~/anaconda3/lib/python3.6/site-packages/pymongo/network.py in _receive_data_on_socket(sock, length)
#     230         while bytes_read < length:
#     231             try:
# --> 232                 chunk_length = sock.recv_into(mv[bytes_read:])
#     233             except (IOError, OSError) as exc:
#     234                 if _errno_from_exception(exc) == errno.EINTR:
#
# KeyboardInterrupt:

# %%
log.debug(f"Stopped scraping at {date_to_scrape}")
# Out:
# DEBUG:__main__:Stopped scraping at 2017-05-09

# %%
date
# Out:
# 54
